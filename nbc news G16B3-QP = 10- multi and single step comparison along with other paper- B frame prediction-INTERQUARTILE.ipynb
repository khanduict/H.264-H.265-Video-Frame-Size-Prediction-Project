# %% [raw]
# Reference
#
# https://github.com/aaxwaz/Multivariate-Time-Series-forecast-using-seq2seq-in-TensorFlow/blob/master/time_series_seq2seq.ipynb
# https://github.com/LukeTonin/keras-seq-2-seq-signal-prediction
# https://github.com/manohar029/TimeSeries-Seq2Seq-deepLSTMs-Keras/blob/master/Keras_Enc-Dec_MinTempMel.ipynb
# https://github.com/aymanshams07/ben-eng-seq2seq-keras/blob/master/lstm.py
# https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/
#
#
# http://www.edscave.com/forecasting---time-series-metrics.html

# %% [markdown]
# # Many to many models

# %% [markdown]
# ***import library***

# %%
import numpy as np
import pandas as pd


from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

#import seaborn as sns
from sklearn.metrics import mean_squared_error

from sklearn.metrics import r2_score

import os
import datetime
from math import sqrt

import math
from tensorflow.keras import backend
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, SimpleRNN

from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D, Dropout, Flatten
from keras.layers import  regularizers

from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense, LSTM, Flatten, Input, Reshape
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Lambda, Flatten
import tensorflow.keras.backend as K
from sklearn.model_selection import TimeSeriesSplit

from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.python.keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ***import data***

# %%
#import data
data = pd.read_csv("../VIDEO TRAFFIC/FINAL comparison -benchmark models/data/nbc news G16B3-QP = 10-1.csv",
                  names=['decoded_frame','arrival_time', 'video_frame', 
                                         'frame_size', 'x', 'y', 'z'])

# %%
data.head()
# Out:
#    decoded_frame  arrival_time video_frame  frame_size       x       y       z
# 0             16     533.33333           I      237784  52.353  52.474  52.951
# 1             13     433.33333           B      191888  48.114  49.612  50.446
# 2             14     466.66667           B      198992  48.003  49.608  50.231
# 3             15     500.00000           B      136112  48.290  50.312  51.118
# 4             20     666.66667           P      296416  49.951  50.910  51.201

# %%
data.dropna(0,inplace= True)

# %%
#drop decoded frame column
data.drop(('decoded_frame'), axis=1, inplace=True)

data.drop(('x'), axis=1, inplace=True)
data.drop(('y'), axis=1, inplace=True)
data.drop(('z'), axis=1, inplace=True)

# %%
frame_size = data.frame_size
plt.figure(figsize= (7,3))
frame_size.plot()
plt.title("G16B3_QP28_verbose")
plt.ylabel("frame_size")
plt.show()

# %%
# Label encoding of species column numerically
le = LabelEncoder()
le.fit(data['video_frame'])
print(list(le.classes_))
data['video_frame'] = le.transform(data['video_frame'])
# Out:
# ['B', 'I', 'P']

# %%
data.head(5)
# Out:
#    arrival_time  video_frame  frame_size
# 0     533.33333            1      237784
# 1     433.33333            0      191888
# 2     466.66667            0      198992
# 3     500.00000            0      136112
# 4     666.66667            2      296416

# %%
# data labels
labels_index = { "B" : 0, "I" : 1, "P" : 2}

# %%
indexNames1 = data[data['video_frame'] == 0 ].index

# Delete these row indexes from dataFrame
data.drop(indexNames1 , inplace=True)

# %%
data.head()
# Out:
#     arrival_time  video_frame  frame_size
# 0      533.33333            1      237784
# 4      666.66667            2      296416
# 8      800.00000            2      289312
# 12     933.33333            2      288384
# 16    1066.66667            1      259272

# %%
data.shape
# Out:
# (2962, 3)

# %% [raw]
# # calculate interquartile range
# q25, q75 = np.percentile(data['frame_size'], 2), np.percentile(data['frame_size'], 99)
# iqr = q75 - q25

# %% [raw]
# iqr

# %% [raw]
# ## let's remove all observations that have frames higher than iqr value
# data = data[data['frame_size'] <= iqr]

# %% [raw]
# print('original df size:', data.shape)

# %%
data.frame_size.dropna(0, inplace=True)
dataset = data.frame_size.values #numpy.ndarray
#dataset = dataset.astype('float32')
dataset.shape
# Out:
# (1897,)

# %%
dataset = pd.DataFrame(dataset)
print(dataset.shape)
# Out:
# (1897, 1)

# %%
# *****************split into train and test sets********************

test_split = int(len(dataset) * 0.8)
X_train = dataset[:test_split]
y_train = dataset [:test_split]
X_test = dataset[test_split:]
y_test = dataset[test_split:]
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1517, 1) (1517, 1) (380, 1) (380, 1)

# %%
#---NORMALIZE DATA---

scaler = MinMaxScaler(feature_range=(-1, 1))

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

y_train = scaler.fit_transform(y_train)
y_test = scaler.transform(y_test)

print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (1517, 1) (1517, 1)
# (380, 1) (380, 1)

# %% [markdown]
# ***Define parameters***

# %%
# num of input signals
#input_dim = X_train.shape[1]
# num of output signals
#output_dim = y_train.shape[1]


input_seq_len = 16
output_seq_len = 8
num_input_features = 1
num_output_features = 1
batch_size = 10

# %%
def generate_train_sequences(x):
    
    total_start_points = len(x) - input_seq_len - output_seq_len
    start_x_idx = np.random.choice(range(total_start_points), total_start_points, replace = False)
    
    input_batch_idxs = [(range(i, i+input_seq_len)) for i in start_x_idx]
    input_seq = np.take(x, input_batch_idxs, axis = 0)
    
    output_batch_idxs = [(range(i+input_seq_len, i+input_seq_len+output_seq_len)) for i in start_x_idx]
    output_seq = np.take(x, output_batch_idxs, axis = 0)
    
    input_seq =(input_seq.reshape(input_seq.shape[0],input_seq.shape[1],num_input_features))
    output_seq=(output_seq.reshape(output_seq.shape[0],output_seq.shape[1],num_output_features))
    
    return input_seq, output_seq

# %%
input_seq, output_seq = generate_train_sequences(X_train)
print(input_seq.shape, output_seq.shape)
# Out:
# (1493, 16, 1) (1493, 8, 1)

# %% [markdown]
# ***Encoder***

# %%
# Define an input series and encode it with an LSTM. 

encoder_inputs = tf.keras.layers.Input(shape=(None, num_input_features)) 
encoder = LSTM(128, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the final states. These represent the "context"
# vector that we use as the basis for decoding.
encoder_states = [state_h, state_c]

# %% [markdown]
# ***Decoder***

# %%
# Set up the decoder, using `encoder_states` as initial state.
# This is where teacher forcing inputs are fed in.
decoder_inputs = tf.keras.layers.Input(shape=(None, 1)) 


# We set up our decoder using `encoder_states` as initial state.  
# We return full output sequences and return internal states as well. 
# We don't use the return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(128,  return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)

decoder_dense = Dense(1) # 1 continuous output at each timestep
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
#model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model = Model(inputs=[encoder_inputs, decoder_inputs], outputs=decoder_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None, 1)]    0
# __________________________________________________________________________________________________
# unified_lstm (UnifiedLSTM)      [(None, 128), (None, 66560       input_1[0][0]
# __________________________________________________________________________________________________
# unified_lstm_1 (UnifiedLSTM)    [(None, None, 128),  66560       input_2[0][0]
#                                                                  unified_lstm[0][1]
#                                                                  unified_lstm[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 1)      129         unified_lstm_1[0][0]
# ==================================================================================================
# Total params: 133,249
# Trainable params: 133,249
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(lr=0.001)
model.compile(loss='mse', optimizer= optimizer, metrics=[ 'mse'])

# %%
input_seq, output_seq = generate_train_sequences(X_train)

encoder_input_data = input_seq
decoder_target_data = output_seq
decoder_input_data = np.zeros(decoder_target_data.shape)

history = model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
                             batch_size=batch_size,
                             epochs= 100,
                             validation_split=0.1, 
                             shuffle=False)
# Out:
# Train on 1343 samples, validate on 150 samples
# Epoch 1/100
# 1343/1343 [==============================] - 2s 2ms/sample - loss: 0.1448 - mse: 0.1448 - val_loss: 0.1500 - val_mse: 0.1500
# Epoch 2/100
# 1343/1343 [==============================] - 1s 993us/sample - loss: 0.1392 - mse: 0.1392 - val_loss: 0.1483 - val_mse: 0.1483
# Epoch 3/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1385 - mse: 0.1385 - val_loss: 0.1470 - val_mse: 0.1470
# Epoch 4/100
# 1343/1343 [==============================] - 1s 999us/sample - loss: 0.1381 - mse: 0.1381 - val_loss: 0.1463 - val_mse: 0.1463
# Epoch 5/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1377 - mse: 0.1377 - val_loss: 0.1460 - val_mse: 0.1460
# Epoch 6/100
# 1343/1343 [==============================] - 1s 993us/sample - loss: 0.1375 - mse: 0.1375 - val_loss: 0.1457 - val_mse: 0.1457
# Epoch 7/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1373 - mse: 0.1373 - val_loss: 0.1454 - val_mse: 0.1454
# Epoch 8/100
# 1343/1343 [==============================] - 1s 993us/sample - loss: 0.1371 - mse: 0.1371 - val_loss: 0.1450 - val_mse: 0.1450
# Epoch 9/100
# 1343/1343 [==============================] - 2s 1ms/sample - loss: 0.1369 - mse: 0.1369 - val_loss: 0.1448 - val_mse: 0.1448
# Epoch 10/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1367 - mse: 0.1367 - val_loss: 0.1447 - val_mse: 0.1447
# Epoch 11/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1365 - mse: 0.1365 - val_loss: 0.1445 - val_mse: 0.1445
# Epoch 12/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1363 - mse: 0.1363 - val_loss: 0.1439 - val_mse: 0.1439
# Epoch 13/100
# 1343/1343 [==============================] - 2s 1ms/sample - loss: 0.1359 - mse: 0.1359 - val_loss: 0.1426 - val_mse: 0.1426
# Epoch 14/100
# 1343/1343 [==============================] - 2s 1ms/sample - loss: 0.1353 - mse: 0.1353 - val_loss: 0.1424 - val_mse: 0.1424
# Epoch 15/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1345 - mse: 0.1345 - val_loss: 0.1431 - val_mse: 0.1431
# Epoch 16/100
# 1343/1343 [==============================] - 2s 1ms/sample - loss: 0.1357 - mse: 0.1357 - val_loss: 0.1429 - val_mse: 0.1429
# Epoch 17/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1342 - mse: 0.1342 - val_loss: 0.1420 - val_mse: 0.1420
# Epoch 18/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1333 - mse: 0.1333 - val_loss: 0.1412 - val_mse: 0.1412
# Epoch 19/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1322 - mse: 0.1322 - val_loss: 0.1408 - val_mse: 0.1408
# Epoch 20/100
# 1343/1343 [==============================] - 1s 997us/sample - loss: 0.1317 - mse: 0.1317 - val_loss: 0.1416 - val_mse: 0.1416
# Epoch 21/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1311 - mse: 0.1311 - val_loss: 0.1423 - val_mse: 0.1423
# Epoch 22/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1302 - mse: 0.1302 - val_loss: 0.1418 - val_mse: 0.1418
# Epoch 23/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1297 - mse: 0.1297 - val_loss: 0.1415 - val_mse: 0.1415
# Epoch 24/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1284 - mse: 0.1284 - val_loss: 0.1427 - val_mse: 0.1427
# Epoch 25/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1258 - mse: 0.1258 - val_loss: 0.1419 - val_mse: 0.1419
# Epoch 26/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1219 - mse: 0.1219 - val_loss: 0.1322 - val_mse: 0.1322
# Epoch 27/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1182 - mse: 0.1182 - val_loss: 0.1274 - val_mse: 0.1274
# Epoch 28/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1146 - mse: 0.1146 - val_loss: 0.1296 - val_mse: 0.1296
# Epoch 29/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1123 - mse: 0.1123 - val_loss: 0.1233 - val_mse: 0.1233
# Epoch 30/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1077 - mse: 0.1077 - val_loss: 0.1247 - val_mse: 0.1247
# Epoch 31/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1046 - mse: 0.1046 - val_loss: 0.1156 - val_mse: 0.1156
# Epoch 32/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1008 - mse: 0.1008 - val_loss: 0.1128 - val_mse: 0.1128
# Epoch 33/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.1013 - mse: 0.1013 - val_loss: 0.1124 - val_mse: 0.1124
# Epoch 34/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0980 - mse: 0.0980 - val_loss: 0.1132 - val_mse: 0.1132
# Epoch 35/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0950 - mse: 0.0950 - val_loss: 0.1094 - val_mse: 0.1094
# Epoch 36/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0945 - mse: 0.0945 - val_loss: 0.1105 - val_mse: 0.1105
# Epoch 37/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0900 - mse: 0.0900 - val_loss: 0.1067 - val_mse: 0.1067
# Epoch 38/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0890 - mse: 0.0890 - val_loss: 0.1008 - val_mse: 0.1008
# Epoch 39/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0854 - mse: 0.0854 - val_loss: 0.1011 - val_mse: 0.1011
# Epoch 40/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0832 - mse: 0.0832 - val_loss: 0.1033 - val_mse: 0.1033
# Epoch 41/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0824 - mse: 0.0824 - val_loss: 0.0990 - val_mse: 0.0990
# Epoch 42/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0782 - mse: 0.0782 - val_loss: 0.0967 - val_mse: 0.0967
# Epoch 43/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0752 - mse: 0.0752 - val_loss: 0.0995 - val_mse: 0.0995
# Epoch 44/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0738 - mse: 0.0738 - val_loss: 0.0959 - val_mse: 0.0959
# Epoch 45/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0697 - mse: 0.0697 - val_loss: 0.0918 - val_mse: 0.0918
# Epoch 46/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0663 - mse: 0.0663 - val_loss: 0.0976 - val_mse: 0.0976
# Epoch 47/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0655 - mse: 0.0655 - val_loss: 0.1009 - val_mse: 0.1009
# Epoch 48/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0627 - mse: 0.0627 - val_loss: 0.1025 - val_mse: 0.1025
# Epoch 49/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0613 - mse: 0.0613 - val_loss: 0.0957 - val_mse: 0.0957
# Epoch 50/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0570 - mse: 0.0570 - val_loss: 0.0904 - val_mse: 0.0904
# Epoch 51/100
# 1343/1343 [==============================] - 1s 988us/sample - loss: 0.0536 - mse: 0.0536 - val_loss: 0.0858 - val_mse: 0.0858
# Epoch 52/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0523 - mse: 0.0523 - val_loss: 0.0876 - val_mse: 0.0876
# Epoch 53/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0515 - mse: 0.0515 - val_loss: 0.0836 - val_mse: 0.0836
# Epoch 54/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0477 - mse: 0.0477 - val_loss: 0.0778 - val_mse: 0.0778
# Epoch 55/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0442 - mse: 0.0442 - val_loss: 0.0817 - val_mse: 0.0817
# Epoch 56/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0435 - mse: 0.0435 - val_loss: 0.0799 - val_mse: 0.0799
# Epoch 57/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0751 - val_mse: 0.0751
# Epoch 58/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0411 - mse: 0.0411 - val_loss: 0.0738 - val_mse: 0.0738
# Epoch 59/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0388 - mse: 0.0388 - val_loss: 0.0749 - val_mse: 0.0749
# Epoch 60/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0398 - mse: 0.0398 - val_loss: 0.0756 - val_mse: 0.0756
# Epoch 61/100
# 1343/1343 [==============================] - 1s 979us/sample - loss: 0.0370 - mse: 0.0370 - val_loss: 0.0735 - val_mse: 0.0735
# Epoch 62/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0352 - mse: 0.0352 - val_loss: 0.0719 - val_mse: 0.0719
# Epoch 63/100
# 1343/1343 [==============================] - 1s 996us/sample - loss: 0.0355 - mse: 0.0355 - val_loss: 0.0698 - val_mse: 0.0698
# Epoch 64/100
# 1343/1343 [==============================] - 1s 991us/sample - loss: 0.0351 - mse: 0.0351 - val_loss: 0.0818 - val_mse: 0.0818
# Epoch 65/100
# 1343/1343 [==============================] - 1s 993us/sample - loss: 0.0314 - mse: 0.0314 - val_loss: 0.0666 - val_mse: 0.0666
# Epoch 66/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0315 - mse: 0.0315 - val_loss: 0.0663 - val_mse: 0.0663
# Epoch 67/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0308 - mse: 0.0308 - val_loss: 0.0672 - val_mse: 0.0672
# Epoch 68/100
# 1343/1343 [==============================] - 2s 1ms/sample - loss: 0.0291 - mse: 0.0291 - val_loss: 0.0674 - val_mse: 0.0674
# Epoch 69/100
# 1343/1343 [==============================] - 2s 1ms/sample - loss: 0.0280 - mse: 0.0280 - val_loss: 0.0634 - val_mse: 0.0634
# Epoch 70/100
# 1343/1343 [==============================] - 2s 1ms/sample - loss: 0.0246 - mse: 0.0246 - val_loss: 0.0611 - val_mse: 0.0611
# Epoch 71/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0237 - mse: 0.0237 - val_loss: 0.0634 - val_mse: 0.0634
# Epoch 72/100
# 1343/1343 [==============================] - 1s 985us/sample - loss: 0.0262 - mse: 0.0262 - val_loss: 0.0645 - val_mse: 0.0645
# Epoch 73/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0241 - mse: 0.0241 - val_loss: 0.0653 - val_mse: 0.0653
# Epoch 74/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0256 - mse: 0.0256 - val_loss: 0.0639 - val_mse: 0.0639
# Epoch 75/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0623 - val_mse: 0.0623
# Epoch 76/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0616 - val_mse: 0.0616
# Epoch 77/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0636 - val_mse: 0.0636
# Epoch 78/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0622 - val_mse: 0.0622
# Epoch 79/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0621 - val_mse: 0.0621
# Epoch 80/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0627 - val_mse: 0.0627
# Epoch 81/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0209 - mse: 0.0209 - val_loss: 0.0689 - val_mse: 0.0689
# Epoch 82/100
# 1343/1343 [==============================] - 1s 991us/sample - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0617 - val_mse: 0.0617
# Epoch 83/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0628 - val_mse: 0.0628
# Epoch 84/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0661 - val_mse: 0.0661
# Epoch 85/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0641 - val_mse: 0.0641
# Epoch 86/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0637 - val_mse: 0.0637
# Epoch 87/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0637 - val_mse: 0.0637
# Epoch 88/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0653 - val_mse: 0.0653
# Epoch 89/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 90/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 91/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0564 - val_mse: 0.0564
# Epoch 92/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 93/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0609 - val_mse: 0.0609
# Epoch 94/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0542 - val_mse: 0.0542
# Epoch 95/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 96/100
# 1343/1343 [==============================] - 1s 996us/sample - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 97/100
# 1343/1343 [==============================] - 1s 994us/sample - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0569 - val_mse: 0.0569
# Epoch 98/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 99/100
# 1343/1343 [==============================] - 1s 1ms/sample - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0545 - val_mse: 0.0545
# Epoch 100/100
# 1343/1343 [==============================] - 1s 993us/sample - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0539 - val_mse: 0.0539

# %%
#***************************************Model validation loss*****************************************
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
#plt.title('Model Loss')
plt.ylabel('Mean sequared error loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ***Inference model***

# %%
# define inference encoder
n_units = 128

encoder_model = tf.keras.Model(encoder_inputs, encoder_states)
    
# define inference decoder
decoder_state_input_h = Input(shape=(n_units,))
decoder_state_input_c = Input(shape=(n_units,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = tf.keras.Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# %% [markdown]
# ***Prediction***

# %%
def predict(x, encoder_model, decoder_model, num_steps_to_predict):
    
    y_predicted = []

    # Encode the values as a state vector
    states = encoder_model.predict(x)

    # The states must be a list
    if not isinstance(states, list):
        states = [states]

    # Generate first value of the decoder input sequence
    decoder_input = np.zeros((x.shape[0], 1, 1))


    for _ in range(num_steps_to_predict):
        outputs_and_states = decoder_model.predict([decoder_input] + states, batch_size=batch_size)
        output = outputs_and_states[0]
        states = outputs_and_states[1:]

        # add predicted value
        y_predicted.append(output)

    return np.concatenate(y_predicted, axis=1)

# %%
def generate_test_samples(x = X_test, y = y_test, input_seq_len = input_seq_len, output_seq_len = output_seq_len):
    
    total_samples = x.shape[0]
    
    input_batch_idxs = [list(range(i, i+input_seq_len)) for i in range((total_samples-input_seq_len-output_seq_len))]
    input_seq = np.take(x, input_batch_idxs, axis = 0)
    
    output_batch_idxs = [list(range(i+input_seq_len, i+input_seq_len+output_seq_len)) for i in range((total_samples-input_seq_len-output_seq_len))]
    output_seq = np.take(y, output_batch_idxs, axis = 0)
    
    return input_seq, output_seq

# %%
X_test, y_test = generate_test_samples()
print(X_test.shape, y_test.shape)
# Out:
# (356, 16, 1) (356, 8, 1)

# %%
#from utils import plot_prediction
num_steps_to_predict = 8

y_test_predicted = predict(X_test, encoder_model, decoder_model, num_steps_to_predict)
y_test_predicted.shape
# Out:
# (356, 8, 1)

# %%
y_test.shape
# Out:
# (356, 8, 1)

# %% [markdown]
# ***Plotting***

# %% [raw]
# #Select  random examples to plot
# indices = np.random.choice(range(X_test.shape[0]), replace=False, size=10)
#
# for index in indices:
#     plt.plot(y_test[index, :], y_test_predicted[index, :])

# %%
y_test_predicted = y_test_predicted.reshape(y_test_predicted.shape[0], y_test_predicted.shape[1])
y_test_predicted_inv = scaler.inverse_transform(y_test_predicted)

y_test = y_test.reshape(y_test.shape[0], y_test.shape[1])
y_test_inv = scaler.inverse_transform(y_test)

# %%
plt.plot(y_test_predicted_inv[:100], label = "pred", color ='blue')
plt.plot(y_test_inv[:100], label = "actual", color= 'yellow')
plt.show()

# %%
#********************* Actual value, Predicted value and Prediction Error ***************

plt.figure(figsize = (15, 5))
plt.xlabel("Epoch")
plt.ylabel("Email traffic")
plt.plot(y_test_inv[:,0], label="True value", linewidth=1,linestyle="--",color= 'green')
plt.plot(y_test_predicted_inv[:,0], label="Predicted value", linewidth=1,color='blue')

error = abs(y_test_inv[:,0] - y_test_predicted_inv[:,0])

plt.plot(error, label='Error',color= 'orange', linewidth=1, linestyle="--")
plt.legend()
plt.show()

#******************************* True value vs Prediction **********************/

plt.figure(figsize = (15, 5))
plt.xlabel("Epoch")
plt.ylabel("Email traffic")
plt.plot (y_test_inv[:,0], label="True value", linewidth=1,color= 'green', linestyle="--")
plt.plot(y_test_predicted_inv[:,0], label="Predicted value", linewidth=1,color='blue')
plt.legend()
plt.show()

# %% [markdown]
# ***Performance Evaluation metrics***

# %%
models = pd.DataFrame(index=['MAPE','MAE'], 
                      columns=['seq2seq', 'LSTM_many_to_many','CNN_many_to_many', 'LSTM_many_to_one', 'CNN_many_to_one'])

# %%
import tensorflow.keras.backend as K
from sklearn.metrics import mean_absolute_error

#def rpe1(y_true, y_pred):
    #y_true, y_pred = np.array(y_true), np.array(y_pred)
    #return np.mean(y_true - y_pred)/y_true * 100


def mean_absolute_error1(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs(y_true - y_pred)) * 100


def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


#models.loc['rmse','seq2seq'] = np.sqrt(mean_squared_error(y_test, y_test_predicted))
models.loc['MAPE','seq2seq'] = mean_absolute_percentage_error(y_test, y_test_predicted)
models.loc['MAE', 'seq2seq'] = mean_absolute_error(y_test, y_test_predicted)*100
#models.loc['mae2', 'seq2seq'] = mean_absolute_error1(y_test, y_test_predicted)


# Prediction Time !!!!
mse = round(mean_squared_error(y_test, y_test_predicted), 2)
print('MSE', mse)
rmse = round(sqrt(mse), 2)
print('RMSE', rmse)
# Out:
# MSE 0.15
# RMSE 0.39

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter((y_test_predicted), y_test, s=4)
ax.plot(y_test, y_test, color='red')
ax.set_title('seq2seq model: G16B3_QP28 predicted frame')
ax.set_xlabel('Predicted frame_size')
ax.set_ylabel('Observed frame_size');

# %% [markdown]
# # Multistep model

# %%
data.frame_size.dropna(0, inplace=True)
dataset2 = data.frame_size.values #numpy.ndarray
#dataset = dataset.astype('float32')
dataset2.shape
# Out:
# (1897,)

# %%
dataset2 = pd.DataFrame(dataset2)
print(dataset2.shape)
# Out:
# (1897, 1)

# %%
# *****************split into train and test sets********************

test_split = int(len(dataset2) * 0.8)

train2 = dataset2[:test_split]
test2 = dataset2[test_split:]

# %%
#********Data normalization**************************

scaler = MinMaxScaler(feature_range=(-1, 1))

train2 = scaler.fit_transform(train2)
test2= scaler.transform(test2)

# %%
#****************************Create lagged time series dataset*******************

def prepare_seq2seq_data(dataset, look_back, look_ahead):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - look_ahead):
        input_seq = dataset[i:(i + look_back)]
        output_seq = dataset[i + look_back:(i + look_back + look_ahead)]
        dataX.append(input_seq)
        dataY.append(output_seq)

    dataX = np.reshape(np.array(dataX),[-1,look_back])
    dataY = np.reshape(np.array(dataY),[-1,look_ahead])
    #print (dataY.shape)
    return dataX,dataY

# %%
look_back = 16
look_ahead = 8

X_train, y_train = prepare_seq2seq_data(train2, look_back, look_ahead)
X_test, y_test = prepare_seq2seq_data(test2, look_back, look_ahead)

# %%
#*******Reshape from[samples, timesteps] into [samples, timesteps, features]*************

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

print('X_train',X_train.shape)
print('X_test', X_test.shape)

# convert 1 D to 2D array
#test_y = test_y.reshape((test_y.shape[0], 1))
#print(test_y.shape)
# Out:
# X_train (1493, 16, 1)
# X_test (356, 16, 1)

# %% [markdown]
# ***LSTM model multistep***

# %%
#********************Build Model****************************

def lstm_model():
    
    model = tf.keras.models.Sequential()
    model.add(LSTM(128, input_shape=(look_back,1),kernel_regularizer=regularizers.l2(0.001)
                ))
    #model.add(tf.keras.layers.Dropout(rate=0.20))
    #model.add(LSTM(64, kernel_regularizer=regularizers.l2(0.001)))
    #model.add(tf.keras.layers.Dropout(rate=0.20))
    #model.add(LSTM(128, kernel_initializer='glorot_uniform',activation='relu'))
    model.add(Dense(look_ahead))
    model.summary()
    
     #optimizer = tf.keras.optimizers.Adam(lr=0.0001)
    model.compile(optimizer= 'adam', loss='mse')
      
    return model

# %%
#*******************Train the model******************************

callback_early_stopping = EarlyStopping(monitor='val_loss', patience=1000, verbose=1)
callbacks = [callback_early_stopping]

model_lstm =lstm_model()


history_lstm = model_lstm.fit(X_train, y_train, batch_size = 32,validation_split=0.2, epochs =100, verbose=1,
                    callbacks=callbacks, shuffle=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# unified_lstm_2 (UnifiedLSTM) (None, 128)               66560
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 1032
# =================================================================
# Total params: 67,592
# Trainable params: 67,592
# Non-trainable params: 0
# _________________________________________________________________
# Train on 
# Epoch 89/100
# 1194/1194 [==============================] - 0s 304us/sample - loss: 0.0971 - val_loss: 0.1315
# Epoch 90/100
# 1194/1194 [==============================] - 0s 289us/sample - loss: 0.0968 - val_loss: 0.1298
# Epoch 91/100
# 1194/1194 [==============================] - 0s 286us/sample - loss: 0.0968 - val_loss: 0.1293
# Epoch 92/100
# 1194/1194 [==============================] - 0s 313us/sample - loss: 0.0965 - val_loss: 0.1302
# Epoch 93/100
# 1194/1194 [==============================] - 0s 286us/sample - loss: 0.0963 - val_loss: 0.1315
# Epoch 94/100
# 1194/1194 [==============================] - 0s 343us/sample - loss: 0.0977 - val_loss: 0.1339
# Epoch 95/100
# 1194/1194 [==============================] - 0s 305us/sample - loss: 0.0977 - val_loss: 0.1372
# Epoch 96/100
# 1194/1194 [==============================] - 0s 299us/sample - loss: 0.0959 - val_loss: 0.1322
# Epoch 97/100
# 1194/1194 [==============================] - 0s 293us/sample - loss: 0.0949 - val_loss: 0.1375
# Epoch 98/100
# 1194/1194 [==============================] - 0s 296us/sample - loss: 0.0946 - val_loss: 0.1298
# Epoch 99/100
# 1194/1194 [==============================] - 0s 328us/sample - loss: 0.0982 - val_loss: 0.1351
# Epoch 100/100
# 1194/1194 [==============================] - 0s 320us/sample - loss: 0.0961 - val_loss: 0.1336

# %%
# Prediction Time !!!!


yhat_lstm = model_lstm.predict(X_test)

mse_lstm = mean_squared_error(y_test, yhat_lstm)
rmse_lstm = sqrt(mse_lstm)

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


#models.loc['rmse','LSTM_many_to_many'] = np.sqrt(mean_squared_error(y_test, yhat_lstm))
models.loc['MAPE','LSTM_many_to_many'] = mean_absolute_percentage_error(y_test, yhat_lstm)
models.loc['MAE','LSTM_many_to_many'] = mean_absolute_error(y_test, yhat_lstm)*100

# %% [markdown]
# ***CNN model multistep***

# %%
#********************Build Model****************************

def cnn_model():
    
    model = tf.keras.models.Sequential()
    model.add(Conv1D(filters=128, kernel_size=3, strides=1, input_shape=(look_back,1)
                    ))
    model.add(MaxPooling1D(pool_size=(2)))
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(look_ahead))
    model.compile(optimizer='adam', loss='mse')
    model.summary()
      
    return model

# %%
model_cnn =cnn_model()

history_cnn = model_cnn.fit(X_train, y_train, batch_size = 32,validation_split=0.2, epochs = 100, verbose=1,
                    callbacks=callbacks, shuffle=False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 14, 128)           512
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 7, 128)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 896)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 896)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 7176
# =================================================================
# Total params: 7,688
# Trainable params: 7,688
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1194 samples, validate on 299 samples
# Epoch 1/100
# 1194/1194 [==============================] - 0s 282us/sample - loss: 0.1762 - val_loss: 0.1309
# Epoch 2/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1508 - val_loss: 0.1249
# Epoch 3/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1444 - val_loss: 0.1234
# Epoch 4/100
# 1194/1194 [==============================] - 0s 73us/sample - loss: 0.1420 - val_loss: 0.1223
# Epoch 5/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1399 - val_loss: 0.1212
# Epoch 6/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1381 - val_loss: 0.1205
# Epoch 7/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1371 - val_loss: 0.1198
# Epoch 8/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1359 - val_loss: 0.1191
# Epoch 9/100
# 1194/1194 [==============================] - 0s 77us/sample - loss: 0.1356 - val_loss: 0.1192
# Epoch 10/100
# 1194/1194 [==============================] - 0s 80us/sample - loss: 0.1340 - val_loss: 0.1190
# Epoch 11/100
# 1194/1194 [==============================] - 0s 82us/sample - loss: 0.1343 - val_loss: 0.1189
# Epoch 12/100
# 1194/1194 [==============================] - 0s 77us/sample - loss: 0.1331 - val_loss: 0.1185
# Epoch 13/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1329 - val_loss: 0.1186
# Epoch 14/100
# 1194/1194 [==============================] - 0s 73us/sample - loss: 0.1324 - val_loss: 0.1186
# Epoch 15/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1324 - val_loss: 0.1188
# Epoch 16/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1320 - val_loss: 0.1185
# Epoch 17/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1318 - val_loss: 0.1186
# Epoch 18/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1308 - val_loss: 0.1187
# Epoch 19/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1315 - val_loss: 0.1188
# Epoch 20/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1309 - val_loss: 0.1186
# Epoch 21/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1311 - val_loss: 0.1186
# Epoch 22/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1314 - val_loss: 0.1188
# Epoch 23/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1312 - val_loss: 0.1187
# Epoch 24/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1304 - val_loss: 0.1186
# Epoch 25/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1301 - val_loss: 0.1187
# Epoch 26/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1304 - val_loss: 0.1190
# Epoch 27/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1306 - val_loss: 0.1189
# Epoch 28/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1302 - val_loss: 0.1187
# Epoch 29/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1310 - val_loss: 0.1186
# Epoch 30/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1297 - val_loss: 0.1190
# Epoch 31/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1291 - val_loss: 0.1189
# Epoch 32/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1298 - val_loss: 0.1187
# Epoch 33/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1300 - val_loss: 0.1189
# Epoch 34/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1300 - val_loss: 0.1189
# Epoch 35/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1294 - val_loss: 0.1188
# Epoch 36/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1294 - val_loss: 0.1186
# Epoch 37/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1294 - val_loss: 0.1188
# Epoch 38/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1298 - val_loss: 0.1189
# Epoch 39/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1290 - val_loss: 0.1190
# Epoch 40/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1291 - val_loss: 0.1189
# Epoch 41/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1299 - val_loss: 0.1188
# Epoch 42/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1295 - val_loss: 0.1188
# Epoch 43/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1292 - val_loss: 0.1189
# Epoch 44/100
# 1194/1194 [==============================] - 0s 73us/sample - loss: 0.1293 - val_loss: 0.1189
# Epoch 45/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1291 - val_loss: 0.1188
# Epoch 46/100
# 1194/1194 [==============================] - 0s 72us/sample - loss: 0.1293 - val_loss: 0.1191
# Epoch 47/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1299 - val_loss: 0.1190
# Epoch 48/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1290 - val_loss: 0.1190
# Epoch 49/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1288 - val_loss: 0.1191
# Epoch 50/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1288 - val_loss: 0.1191
# Epoch 51/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1287 - val_loss: 0.1189
# Epoch 52/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1285 - val_loss: 0.1190
# Epoch 53/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1286 - val_loss: 0.1191
# Epoch 54/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1290 - val_loss: 0.1189
# Epoch 55/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1293 - val_loss: 0.1192
# Epoch 56/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1289 - val_loss: 0.1191
# Epoch 57/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1283 - val_loss: 0.1190
# Epoch 58/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1298 - val_loss: 0.1190
# Epoch 59/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1296 - val_loss: 0.1191
# Epoch 60/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1289 - val_loss: 0.1190
# Epoch 61/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1281 - val_loss: 0.1191
# Epoch 62/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1288 - val_loss: 0.1192
# Epoch 63/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1281 - val_loss: 0.1191
# Epoch 64/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1281 - val_loss: 0.1192
# Epoch 65/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1288 - val_loss: 0.1193
# Epoch 66/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1284 - val_loss: 0.1190
# Epoch 67/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1282 - val_loss: 0.1192
# Epoch 68/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1290 - val_loss: 0.1192
# Epoch 69/100
# 1194/1194 [==============================] - 0s 67us/sample - loss: 0.1284 - val_loss: 0.1192
# Epoch 70/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1286 - val_loss: 0.1191
# Epoch 71/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1283 - val_loss: 0.1192
# Epoch 72/100
# 1194/1194 [==============================] - 0s 67us/sample - loss: 0.1283 - val_loss: 0.1192
# Epoch 73/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1281 - val_loss: 0.1193
# Epoch 74/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1284 - val_loss: 0.1192
# Epoch 75/100
# 1194/1194 [==============================] - 0s 66us/sample - loss: 0.1277 - val_loss: 0.1191
# Epoch 76/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1282 - val_loss: 0.1192
# Epoch 77/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1287 - val_loss: 0.1194
# Epoch 78/100
# 1194/1194 [==============================] - 0s 67us/sample - loss: 0.1283 - val_loss: 0.1192
# Epoch 79/100
# 1194/1194 [==============================] - 0s 67us/sample - loss: 0.1288 - val_loss: 0.1192
# Epoch 80/100
# 1194/1194 [==============================] - 0s 66us/sample - loss: 0.1288 - val_loss: 0.1193
# Epoch 81/100
# 1194/1194 [==============================] - 0s 67us/sample - loss: 0.1283 - val_loss: 0.1192
# Epoch 82/100
# 1194/1194 [==============================] - 0s 67us/sample - loss: 0.1290 - val_loss: 0.1192
# Epoch 83/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1278 - val_loss: 0.1192
# Epoch 84/100
# 1194/1194 [==============================] - 0s 66us/sample - loss: 0.1285 - val_loss: 0.1192
# Epoch 85/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1287 - val_loss: 0.1193
# Epoch 86/100
# 1194/1194 [==============================] - 0s 67us/sample - loss: 0.1281 - val_loss: 0.1191
# Epoch 87/100
# 1194/1194 [==============================] - 0s 66us/sample - loss: 0.1277 - val_loss: 0.1191
# Epoch 88/100
# 1194/1194 [==============================] - 0s 67us/sample - loss: 0.1285 - val_loss: 0.1190
# Epoch 89/100
# 1194/1194 [==============================] - 0s 66us/sample - loss: 0.1282 - val_loss: 0.1193
# Epoch 90/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1282 - val_loss: 0.1194
# Epoch 91/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1287 - val_loss: 0.1189
# Epoch 92/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1284 - val_loss: 0.1191
# Epoch 93/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1282 - val_loss: 0.1191
# Epoch 94/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1283 - val_loss: 0.1194
# Epoch 95/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1288 - val_loss: 0.1189
# Epoch 96/100
# 1194/1194 [==============================] - 0s 69us/sample - loss: 0.1286 - val_loss: 0.1190
# Epoch 97/100
# 1194/1194 [==============================] - 0s 71us/sample - loss: 0.1288 - val_loss: 0.1193
# Epoch 98/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1281 - val_loss: 0.1192
# Epoch 99/100
# 1194/1194 [==============================] - 0s 68us/sample - loss: 0.1281 - val_loss: 0.1191
# Epoch 100/100
# 1194/1194 [==============================] - 0s 70us/sample - loss: 0.1278 - val_loss: 0.1192

# %%
#***************************************Model validation loss*****************************************
plt.figure()
plt.plot(history_cnn.history['loss'])
plt.plot(history_cnn.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Validation loss')
plt.xlabel('Epoch')
plt.legend(['Training data loss', 'Validation data loss'], loc='upper right')
plt.show()

# %%
# Prediction Time !!!!
yhat_cnn = model_cnn.predict(X_test)
mse_cnn = mean_squared_error(y_test, yhat_cnn)
rmse_cnn = sqrt(mse_cnn)

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

#models.loc['rmse','CNN_many_to_many'] = np.sqrt(mean_squared_error(y_test, yhat_cnn))
models.loc['MAPE','CNN_many_to_many'] = mean_absolute_percentage_error(y_test, yhat_cnn)
models.loc['MAE','CNN_many_to_many'] = mean_absolute_error(y_test, yhat_cnn)*100

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(model_lstm.predict(X_test), y_test, s=4)
ax.plot(y_test, y_test, color='red')
ax.set_title(' LSTM model: G16B3_QP28 predicted frame')
ax.set_xlabel('Predicted frame_size')
ax.set_ylabel('Observed frame_size');

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(model_cnn.predict(X_test), y_test, s=4)
ax.plot(y_test, y_test, color='red')
ax.set_title('CNN model: G16B3_QP28 predicted frame')
ax.set_xlabel('Predicted frame_size')
ax.set_ylabel('Observed frame_size');

# %% [markdown]
# # single-step models

# %% [markdown]
# ***Single-step LSTM model***

# %%
data.frame_size.dropna(0, inplace=True)
dataset2 = data.frame_size.values #numpy.ndarray
#dataset = dataset.astype('float32')
dataset2.shape
# Out:
# (1897,)

# %%
dataset2 = pd.DataFrame(dataset2)
print(dataset2.shape)
# Out:
# (1897, 1)

# %%
# *****************split into train and test sets********************

test_split = int(len(dataset2) * 0.8)

train2 = dataset2[:test_split]
test2 = dataset2[test_split:]

# %%
#********Data normalization**************************

scaler = MinMaxScaler(feature_range=(-1, 1))

train2 = scaler.fit_transform(train2)
test2 = scaler.transform(test2)

# %%
# ******************frame a lagged sequence problem*************

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)
    
look_back = 16
X_train, y_train = create_dataset(train2, look_back)
X_test, y_test = create_dataset(test2, look_back)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1500, 16) (1500,)
# (363, 16) (363,)

# %%
#*******Reshape from[samples, timesteps] into [samples, timesteps, features]*************

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

print('X_train',X_train.shape)
print('X_test', X_test.shape)

# convert 1 D to 2D array
#test_y = test_y.reshape((test_y.shape[0], 1))
#print(test_y.shape)
# Out:
# X_train (1500, 16, 1)
# X_test (363, 16, 1)

# %%
#********************Build Model****************************

def single_step_lstm_model():
    
    model = tf.keras.models.Sequential()
    model.add(LSTM(128, input_shape=(look_back,1),kernel_regularizer=regularizers.l2(0.001)
               return_sequences=True ))
    #model.add(tf.keras.layers.Dropout(rate=0.20))
    #model.add(LSTM(64, kernel_regularizer=regularizers.l2(0.001)))
    #model.add(tf.keras.layers.Dropout(rate=0.20))
    model.add(LSTM(128, kernel_initializer='glorot_uniform',activation='relu'))
    model.add(Dense(1))
    model.summary()
    
     #optimizer = tf.keras.optimizers.Adam(lr=0.0001)
    model.compile(optimizer= 'adam', loss='mse')
      
    return model

# %%
#*******************Train the model******************************

callback_early_stopping = EarlyStopping(monitor='val_loss', patience=1000, verbose=1)
callbacks = [callback_early_stopping]

single_step_model_lstm = single_step_lstm_model()


history_lstm_single_step = single_step_model_lstm.fit(X_train, y_train, batch_size = 32,validation_split=0.2,
                                                      epochs =100, verbose=1,
                    callbacks=callbacks, shuffle=False)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# unified_lstm_3 (UnifiedLSTM) (None, 128)               66560
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1200 samples, validate on 300 samples
# Epoch 1/100
# 1200/1200 [==============================] - 1s 680us/sample - loss: 0.1404 - val_loss: 0.0988
# Epoch 2/100
# 1200/1200 [==============================] - 0s 297us/sample - loss: 0.1267 - val_loss: 0.0972
# Epoch 3/100
# 1200/1200 [==============================] - 0s 295us/sample - loss: 0.1230 - val_loss: 0.0897
# Epoch 4/100
# 1200/1200 [==============================] - 0s 288us/sample - loss: 0.1207 - val_loss: 0.0857
# Epoch 5/100
# 1200/1200 [==============================] - 0s 291us/sample - loss: 0
100
# 1200/1200 [==============================] - 0s 291us/sample - loss: 0.0788 - val_loss: 0.0803
# Epoch 42/100
# 1200/1200 [==============================] - 0s 293us/sample - loss: 0.0774 - val_loss: 0.0803
# Epoch 43/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0767 - val_loss: 0.0796
# Epoch 44/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0763 - val_loss: 0.0794
# Epoch 45/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0760 - val_loss: 0.0796
# Epoch 46/100
# 1200/1200 [==============================] - 0s 300us/sample - loss: 0.0753 - val_loss: 0.0797
# Epoch 47/100
# 1200/1200 [==============================] - 0s 281us/sample - loss: 0.0748 - val_loss: 0.0799
# Epoch 48/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0741 - val_loss: 0.0800
# Epoch 49/100
# 1200/1200 [==============================] - 0s 304us/sample - loss: 0.0737 - val_loss: 0.0804
# Epoch 50/100
# 1200/1200 [==============================] - 0s 337us/sample - loss: 0.0731 - val_loss: 0.0805
# Epoch 51/100
# 1200/1200 [==============================] - 0s 322us/sample - loss: 0.0729 - val_loss: 0.0815
# Epoch 52/100
# 1200/1200 [==============================] - 0s 322us/sample - loss: 0.0724 - val_loss: 0.0804
# Epoch 53/100
# 1200/1200 [==============================] - 0s 293us/sample - loss: 0.0753 - val_loss: 0.0807
# Epoch 54/100
# 1200/1200 [==============================] - 0s 283us/sample - loss: 0.0733 - val_loss: 0.0807
# Epoch 55/100
# 1200/1200 [==============================] - 0s 318us/sample - loss: 0.0724 - val_loss: 0.0827
# Epoch 56/100
# 1200/1200 [==============================] - 0s 287us/sample - loss: 0.0744 - val_loss: 0.0828
# Epoch 57/100
# 1200/1200 [==============================] - 0s 290us/sample - loss: 0.0719 - val_loss: 0.0813
# Epoch 58/100
# 1200/1200 [==============================] - 0s 293us/sample - loss: 0.0734 - val_loss: 0.0807
# Epoch 59/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0707 - val_loss: 0.0801
# Epoch 60/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0694 - val_loss: 0.0827
# Epoch 61/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0693 - val_loss: 0.0810
# Epoch 62/100
# 1200/1200 [==============================] - 0s 291us/sample - loss: 0.0682 - val_loss: 0.0830
# Epoch 63/100
# 1200/1200 [==============================] - 0s 291us/sample - loss: 0.0673 - val_loss: 0.0815
# Epoch 64/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0674 - val_loss: 0.0815
# Epoch 65/100
# 1200/1200 [==============================] - 0s 304us/sample - loss: 0.0673 - val_loss: 0.0824
# Epoch 66/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0660 - val_loss: 0.0843
# Epoch 67/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0643 - val_loss: 0.0859
# Epoch 68/100
# 1200/1200 [==============================] - 0s 288us/sample - loss: 0.0636 - val_loss: 0.0837
# Epoch 69/100
# 1200/1200 [==============================] - 0s 281us/sample - loss: 0.0646 - val_loss: 0.0804
# Epoch 70/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0694 - val_loss: 0.0840
# Epoch 71/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0669 - val_loss: 0.0843
# Epoch 72/100
# 1200/1200 [==============================] - 0s 279us/sample - loss: 0.0645 - val_loss: 0.0844
# Epoch 73/100
# 1200/1200 [==============================] - 0s 291us/sample - loss: 0.0628 - val_loss: 0.0847
# Epoch 74/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0603 - val_loss: 0.0835
# Epoch 75/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0623 - val_loss: 0.0868
# Epoch 76/100
# 1200/1200 [==============================] - 0s 280us/sample - loss: 0.0594 - val_loss: 0.0830
# Epoch 77/100
# 1200/1200 [==============================] - 0s 290us/sample - loss: 0.0597 - val_loss: 0.0818
# Epoch 78/100
# 1200/1200 [==============================] - 0s 295us/sample - loss: 0.0597 - val_loss: 0.0880
# Epoch 79/100
# 1200/1200 [==============================] - 0s 288us/sample - loss: 0.0569 - val_loss: 0.0855
# Epoch 80/100
# 1200/1200 [==============================] - 0s 296us/sample - loss: 0.0579 - val_loss: 0.0878
# Epoch 81/100
# 1200/1200 [==============================] - 0s 296us/sample - loss: 0.0561 - val_loss: 0.0864
# Epoch 82/100
# 1200/1200 [==============================] - 0s 289us/sample - loss: 0.0561 - val_loss: 0.0878
# Epoch 83/100
# 1200/1200 [==============================] - 0s 298us/sample - loss: 0.0546 - val_loss: 0.0875
# Epoch 84/100
# 1200/1200 [==============================] - 0s 287us/sample - loss: 0.0557 - val_loss: 0.0897
# Epoch 85/100
# 1200/1200 [==============================] - 0s 282us/sample - loss: 0.0584 - val_loss: 0.0865
# Epoch 86/100
# 1200/1200 [==============================] - 0s 291us/sample - loss: 0.0632 - val_loss: 0.0890
# Epoch 87/100
# 1200/1200 [==============================] - 0s 293us/sample - loss: 0.0608 - val_loss: 0.0884
# Epoch 88/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0558 - val_loss: 0.0899
# Epoch 89/100
# 1200/1200 [==============================] - 0s 291us/sample - loss: 0.0528 - val_loss: 0.0890
# Epoch 90/100
# 1200/1200 [==============================] - 0s 278us/sample - loss: 0.0521 - val_loss: 0.0902
# Epoch 91/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0508 - val_loss: 0.0911
# Epoch 92/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0506 - val_loss: 0.0911
# Epoch 93/100
# 1200/1200 [==============================] - 0s 291us/sample - loss: 0.0498 - val_loss: 0.0916
# Epoch 94/100
# 1200/1200 [==============================] - 0s 292us/sample - loss: 0.0494 - val_loss: 0.0913
# Epoch 95/100
# 1200/1200 [==============================] - 0s 305us/sample - loss: 0.0499 - val_loss: 0.0925
# Epoch 96/100
# 1200/1200 [==============================] - 0s 279us/sample - loss: 0.0513 - val_loss: 0.0917
# Epoch 97/100
# 1200/1200 [==============================] - 0s 298us/sample - loss: 0.0512 - val_loss: 0.0887
# Epoch 98/100
# 1200/1200 [==============================] - 0s 285us/sample - loss: 0.0529 - val_loss: 0.0923
# Epoch 99/100
# 1200/1200 [==============================] - 0s 291us/sample - loss: 0.0570 - val_loss: 0.0910
# Epoch 100/100
# 1200/1200 [==============================] - 0s 293us/sample - loss: 0.0557 - val_loss: 0.0910

# %%
#***************************************Model validation loss*****************************************
plt.figure()
plt.plot(history_lstm_single_step.history['loss'])
plt.plot(history_lstm_single_step.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Validation loss')
plt.xlabel('Epoch')
plt.legend(['Training data loss', 'Validation data loss'], loc='upper right')
plt.show()

# %%
# convert 1 D to 2D array
y_train = y_train.reshape((y_train.shape[0], 1))
#print(test_y.shape)

# convert 1 D to 2D array
y_test = y_test.reshape((y_test.shape[0], 1))
#print(test_y.shape)

# %%
# Prediction Time !!!!

yhat_lstm_single_step = single_step_model_lstm.predict(X_test)

mse_lstm_single_step = mean_squared_error(y_test, yhat_lstm_single_step)
rmse_lstm = sqrt(mse_lstm_single_step)


def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


#models.loc['rmse','LSTM_many_to_one'] = np.sqrt(mean_squared_error(y_test, yhat_lstm_single_step))
models.loc['MAPE','LSTM_many_to_one'] = mean_absolute_percentage_error(y_test, yhat_lstm_single_step)
models.loc['MAE','LSTM_many_to_one'] = mean_absolute_error(y_test, yhat_lstm_single_step)*100

# %% [markdown]
# ***Single-step CNN model***

# %%
#********************Build Model****************************

def single_step_cnn_model():
    
    model = tf.keras.models.Sequential()
    model.add(Conv1D(filters=128, kernel_size=3, strides=1, input_shape=(look_back,1)
                    ))
    model.add(MaxPooling1D(pool_size=(2)))
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    model.summary()
      
    return model

# %%
single_step_model_cnn = single_step_cnn_model()

history_cnn_single_step = single_step_model_cnn.fit(X_train, y_train, batch_size = 32,validation_split=0.2,
                                                    epochs = 100, verbose=1,
                    callbacks=callbacks, shuffle=False)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 14, 128)           512
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 7, 128)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 896)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 896)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 897
# =================================================================
# Total params: 1,409
# Trainable params: 1,409
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1200 samples, validate on 300 samples
# Epoch 1/100
# 1200/1200 [==============================] - 0s 224us/sample - loss: 0.1464 - val_loss: 0.1026
# Epoch 2/100
# 1200/1200 [==============================] - 0s 79us/sample - loss: 0.1171 - val_loss: 0.0932
# Epoch 3/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.1078 - val_loss: 0.0894
# Epoch 4/100
# 1200/1200 [==============================] - 0s 70us/sample - loss: 0.1025 - val_loss: 0.0876
# Epoch 5/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.1023 - val_loss: 0.0863
# Epoch 6/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0976 - val_loss: 0.0841
# Epoch 7/100
# 1200/1200 [==============================] - 0s 69us/sample - loss: 0.0954 - val_loss: 0.0826
# Epoch 8/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0944 - val_loss: 0.0827
# Epoch 9/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0923 - val_loss: 0.0810
# Epoch 10/100
# 1200/1200 [==============================] - 0s 69us/sample - loss: 0.0912 - val_loss: 0.0797
# Epoch 11/100
# 1200/1200 [==============================] - 0s 69us/sample - loss: 0.0902 - val_loss: 0.0790
# Epoch 12/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0882 - val_loss: 0.0784
# Epoch 13/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0887 - val_loss: 0.0789
# Epoch 14/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0876 - val_loss: 0.0793
# Epoch 15/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0867 - val_loss: 0.0788
# Epoch 16/100
# 1200/1200 [==============================] - 0s 70us/sample - loss: 0.0880 - val_loss: 0.0788
# Epoch 17/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0880 - val_loss: 0.0789
# Epoch 18/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0889 - val_loss: 0.0788
# Epoch 19/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0867 - val_loss: 0.0791
# Epoch 20/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0881 - val_loss: 0.0786
# Epoch 21/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0879 - val_loss: 0.0784
# Epoch 22/100
# 1200/1200 [==============================] - 0s 71us/sample - loss: 0.0863 - val_loss: 0.0782
# Epoch 23/100
# 1200/1200 [==============================] - 0s 69us/sample - loss: 0.0863 - val_loss: 0.0786
# Epoch 24/100
# 1200/1200 [==============================] - 0s 66us/sample - loss: 0.0851 - val_loss: 0.0781
# Epoch 25/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0861 - val_loss: 0.0786
# Epoch 26/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0853 - val_loss: 0.0791
# Epoch 27/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0857 - val_loss: 0.0791
# Epoch 28/100
# 1200/1200 [==============================] - 0s 71us/sample - loss: 0.0865 - val_loss: 0.0796
# Epoch 29/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0867 - val_loss: 0.0792
# Epoch 30/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0868 - val_loss: 0.0791
# Epoch 31/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0850 - val_loss: 0.0800
# Epoch 32/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0870 - val_loss: 0.0800
# Epoch 33/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0852 - val_loss: 0.0802
# Epoch 34/100
# 1200/1200 [==============================] - 0s 70us/sample - loss: 0.0851 - val_loss: 0.0796
# Epoch 35/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0857 - val_loss: 0.0799
# Epoch 36/100
# 1200/1200 [==============================] - 0s 69us/sample - loss: 0.0852 - val_loss: 0.0795
# Epoch 37/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0855 - val_loss: 0.0796
# Epoch 38/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0849 - val_loss: 0.0795
# Epoch 39/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0854 - val_loss: 0.0797
# Epoch 40/100
# 1200/1200 [==============================] - 0s 71us/sample - loss: 0.0848 - val_loss: 0.0799
# Epoch 41/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0840 - val_loss: 0.0802
# Epoch 42/100
# 1200/1200 [==============================] - 0s 72us/sample - loss: 0.0847 - val_loss: 0.0796
# Epoch 43/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0864 - val_loss: 0.0796
# Epoch 44/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0854 - val_loss: 0.0795
# Epoch 45/100
# 1200/1200 [==============================] - 0s 69us/sample - loss: 0.0834 - val_loss: 0.0797
# Epoch 46/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0858 - val_loss: 0.0798
# Epoch 47/100
# 1200/1200 [==============================] - 0s 66us/sample - loss: 0.0849 - val_loss: 0.0800
# Epoch 48/100
# 1200/1200 [==============================] - 0s 65us/sample - loss: 0.0864 - val_loss: 0.0800
# Epoch 49/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0864 - val_loss: 0.0799
# Epoch 50/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0848 - val_loss: 0.0804
# Epoch 51/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0837 - val_loss: 0.0804
# Epoch 52/100
# 1200/1200 [==============================] - 0s 66us/sample - loss: 0.0858 - val_loss: 0.0805
# Epoch 53/100
# 1200/1200 [==============================] - 0s 65us/sample - loss: 0.0858 - val_loss: 0.0798
# Epoch 54/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0841 - val_loss: 0.0802
# Epoch 55/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0845 - val_loss: 0.0802
# Epoch 56/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0843 - val_loss: 0.0800
# Epoch 57/100
# 1200/1200 [==============================] - 0s 65us/sample - loss: 0.0856 - val_loss: 0.0801
# Epoch 58/100
# 1200/1200 [==============================] - 0s 66us/sample - loss: 0.0851 - val_loss: 0.0797
# Epoch 59/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0848 - val_loss: 0.0798
# Epoch 60/100
# 1200/1200 [==============================] - 0s 65us/sample - loss: 0.0847 - val_loss: 0.0797
# Epoch 61/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0844 - val_loss: 0.0801
# Epoch 62/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0855 - val_loss: 0.0800
# Epoch 63/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0841 - val_loss: 0.0801
# Epoch 64/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0842 - val_loss: 0.0802
# Epoch 65/100
# 1200/1200 [==============================] - 0s 65us/sample - loss: 0.0847 - val_loss: 0.0805
# Epoch 66/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0851 - val_loss: 0.0803
# Epoch 67/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0844 - val_loss: 0.0804
# Epoch 68/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0849 - val_loss: 0.0803
# Epoch 69/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0862 - val_loss: 0.0805
# Epoch 70/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0858 - val_loss: 0.0809
# Epoch 71/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0829 - val_loss: 0.0794
# Epoch 72/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0846 - val_loss: 0.0801
# Epoch 73/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0842 - val_loss: 0.0803
# Epoch 74/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0857 - val_loss: 0.0806
# Epoch 75/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0832 - val_loss: 0.0799
# Epoch 76/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0840 - val_loss: 0.0805
# Epoch 77/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0856 - val_loss: 0.0806
# Epoch 78/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0848 - val_loss: 0.0806
# Epoch 79/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0864 - val_loss: 0.0806
# Epoch 80/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0852 - val_loss: 0.0803
# Epoch 81/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0868 - val_loss: 0.0804
# Epoch 82/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0855 - val_loss: 0.0797
# Epoch 83/100
# 1200/1200 [==============================] - 0s 65us/sample - loss: 0.0855 - val_loss: 0.0804
# Epoch 84/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0839 - val_loss: 0.0803
# Epoch 85/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0850 - val_loss: 0.0806
# Epoch 86/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0857 - val_loss: 0.0805
# Epoch 87/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0843 - val_loss: 0.0803
# Epoch 88/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0846 - val_loss: 0.0805
# Epoch 89/100
# 1200/1200 [==============================] - 0s 65us/sample - loss: 0.0847 - val_loss: 0.0803
# Epoch 90/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0848 - val_loss: 0.0803
# Epoch 91/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0837 - val_loss: 0.0806
# Epoch 92/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0849 - val_loss: 0.0798
# Epoch 93/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0844 - val_loss: 0.0799
# Epoch 94/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0852 - val_loss: 0.0793
# Epoch 95/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0852 - val_loss: 0.0799
# Epoch 96/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0837 - val_loss: 0.0800
# Epoch 97/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0865 - val_loss: 0.0806
# Epoch 98/100
# 1200/1200 [==============================] - 0s 74us/sample - loss: 0.0847 - val_loss: 0.0800
# Epoch 99/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0839 - val_loss: 0.0804
# Epoch 100/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0851 - val_loss: 0.0805

# %%
#***************************************Model validation loss*****************************************
plt.figure()
plt.plot(history_cnn_single_step.history['loss'])
plt.plot(history_cnn_single_step.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Validation loss')
plt.xlabel('Epoch')
plt.legend(['Training data loss', 'Validation data loss'], loc='upper right')
plt.show()

# %%
# Prediction Time !!!!

yhat_cnn_single_step = single_step_model_cnn.predict(X_test)

#mse_cnn = mean_squared_error(y_test, yhat_cnn_single_step)
#rmse_cnn = sqrt(mse_cnn)

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

#models.loc['rmse','CNN_many_to_one'] = np.sqrt(mean_squared_error(y_test, yhat_cnn_single_step))
models.loc['MAPE','CNN_many_to_one'] = mean_absolute_percentage_error(y_test, yhat_cnn_single_step)
models.loc['MAE','CNN_many_to_one'] = mean_absolute_error(y_test, yhat_cnn_single_step)*100

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(single_step_model_lstm.predict(X_test), y_test, s=4)
ax.plot(y_test, y_test, color='red')
ax.set_title(' LSTM model_singlestep: G16B3_QP28 predicted frame')
ax.set_xlabel('Predicted frame_size')
ax.set_ylabel('Observed frame_size');

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(single_step_model_cnn.predict(X_test), y_test, s=4)
ax.plot(y_test, y_test, color='red')
ax.set_title('CNN model_singlestep: G16B3_QP28 predicted frame')
ax.set_xlabel('Predicted frame_size')
ax.set_ylabel('Observed frame_size');

# %% [markdown]
# # Visualization

# %%
models
# Out:
#       seq2seq LSTM_many_to_many CNN_many_to_many LSTM_many_to_one  \
# MAPE   135.72           117.407          104.982           87.011
# MAE   30.2605           26.2885          23.5198          18.5582
#
#      CNN_many_to_one
# MAPE         83.7005
# MAE           17.728

# %%
import seaborn as sns
import matplotlib
fig, ax = plt.subplots(figsize=(7,3))

#fig = plt.figure()
#ax = fig.add_subplot(111)
#ax2 = ax.twinx()   # create another axes that shares teh same x-axis as ax
bar_width = 0

#sns.set_style("dark")
#matplotlib.style.use('fivethirtyeight')


models.loc['MAPE'].sort_values().plot(kind='bar', ax=ax,color ='b', alpha=0.9)
models.loc['MAE'].sort_values().plot(kind='bar', ax=ax, color='r', alpha=0.9)
ax.set_title('nbc news G16B3_QP28');
ax.set_xlabel('models')
#ax2.set_ylabel('mape')
ax.set_ylabel('metrics');
ax.tick_params(axis='x', rotation=30)

#plt.xticks(rotation=30, horizontalalignment="center")


plt.legend(loc='best')
plt.show()

# %%
models.plot(kind='bar', width=0.8, figsize=(6,3))
plt.xticks(rotation=30, horizontalalignment="center")
plt.title('nbc news G16B3_QP28');
plt.xlabel('Models')
plt.ylabel('Metrics')
#ax2.set_ylabel('mape')

plt.show()

# %%
# Loss of the model

def plot_history(histories, key=  'loss'):
  #plt.figure(figsize=(15,10))
    
  for name, history in histories:
    plt.plot(history.epoch, history.history[key],
             label=name.title())
    
  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()
  plt.xlim([0,max(history.epoch)])


plot_history([('seq2seq', history),
              ('LSTM_many_to_many', history_lstm),
         
             ('CNN_many_to_many', history_cnn)])

# %%
import seaborn as sns
sns.set_style("dark")


models.plot(kind='bar', width=0.8, figsize=(6,3))
plt.xticks(rotation=30, horizontalalignment="center")
plt.title('Star wars G16B3_QP28');
plt.xlabel('Models')
plt.ylabel('Metrics')
#ax2.set_ylabel('mape')

plt.show()
