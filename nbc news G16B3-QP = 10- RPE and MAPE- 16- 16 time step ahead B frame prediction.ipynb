# %% [raw]
# Reference
#
# https://github.com/aaxwaz/Multivariate-Time-Series-forecast-using-seq2seq-in-TensorFlow/blob/master/time_series_seq2seq.ipynb
# https://github.com/LukeTonin/keras-seq-2-seq-signal-prediction
# https://github.com/manohar029/TimeSeries-Seq2Seq-deepLSTMs-Keras/blob/master/Keras_Enc-Dec_MinTempMel.ipynb
# https://github.com/aymanshams07/ben-eng-seq2seq-keras/blob/master/lstm.py
# https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/
#
#
# http://www.edscave.com/forecasting---time-series-metrics.html

# %% [markdown]
# # Many to many models

# %% [markdown]
# ***import library***

# %%
import numpy as np
import pandas as pd


from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

#import seaborn as sns
from sklearn.metrics import mean_squared_error

from sklearn.metrics import r2_score

import os
import datetime
from math import sqrt

import math
from tensorflow.keras import backend
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, SimpleRNN

from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D, Dropout, Flatten
from keras.layers import  regularizers

from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense, LSTM, Flatten, Input, Reshape
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Lambda, Flatten
import tensorflow.keras.backend as K
from sklearn.model_selection import TimeSeriesSplit

from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.python.keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ***import data***

# %%
#import data
data = pd.read_csv("../VIDEO TRAFFIC/FINAL comparison -benchmark models/data/nbc news G16B3-QP = 10-1.csv",
                  names=['decoded_frame','arrival_time', 'video_frame', 
                                         'frame_size', 'x', 'y', 'z'])

# %%
data.head()
# Out:
#    decoded_frame  arrival_time video_frame  frame_size       x       y       z
# 0             16     533.33333           I      237784  52.353  52.474  52.951
# 1             13     433.33333           B      191888  48.114  49.612  50.446
# 2             14     466.66667           B      198992  48.003  49.608  50.231
# 3             15     500.00000           B      136112  48.290  50.312  51.118
# 4             20     666.66667           P      296416  49.951  50.910  51.201

# %%
data.dropna(0,inplace= True)

# %%
#drop decoded frame column
data.drop(('decoded_frame'), axis=1, inplace=True)

data.drop(('x'), axis=1, inplace=True)
data.drop(('y'), axis=1, inplace=True)
data.drop(('z'), axis=1, inplace=True)

# %%
# Label encoding of species column numerically
le = LabelEncoder()
le.fit(data['video_frame'])
print(list(le.classes_))
data['video_frame'] = le.transform(data['video_frame'])
# Out:
# ['B', 'I', 'P']

# %%
data.head(5)
# Out:
#    arrival_time  video_frame  frame_size
# 0     533.33333            1      237784
# 1     433.33333            0      191888
# 2     466.66667            0      198992
# 3     500.00000            0      136112
# 4     666.66667            2      296416

# %%
# data labels
labels_index = { "B" : 0, "I" : 1, "P" : 2}

# %%
indexNames1 = data[data['video_frame'] == 0 ].index

# Delete these row indexes from dataFrame
data.drop(indexNames1 , inplace=True)

# %%
data.head()
# Out:
#     arrival_time  video_frame  frame_size
# 0      533.33333            1      237784
# 4      666.66667            2      296416
# 8      800.00000            2      289312
# 12     933.33333            2      288384
# 16    1066.66667            1      259272

# %%
data.frame_size.dropna(0, inplace=True)
dataset = data.frame_size.values #numpy.ndarray
#dataset = dataset.astype('float32')
dataset.shape
# Out:
# (2962,)

# %%
dataset = pd.DataFrame(dataset)
print(dataset.shape)
# Out:
# (2962, 1)

# %%
# *****************split into train and test sets********************

test_split = int(len(dataset) * 0.8)
X_train = dataset[:test_split]
y_train = dataset [:test_split]
X_test = dataset[test_split:]
y_test = dataset[test_split:]
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (2369, 1) (2369, 1) (593, 1) (593, 1)

# %%
#---NORMALIZE DATA---

scaler = MinMaxScaler(feature_range=(-1, 1))

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

y_train = scaler.fit_transform(y_train)
y_test = scaler.transform(y_test)

print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (2369, 1) (2369, 1)
# (593, 1) (593, 1)

# %% [markdown]
# ***Define parameters***

# %%
# num of input signals
#input_dim = X_train.shape[1]
# num of output signals
#output_dim = y_train.shape[1]


input_seq_len = 16
output_seq_len = 16
num_input_features = 1
num_output_features = 1
batch_size = 10

# %%
def generate_train_sequences(x):
    
    total_start_points = len(x) - input_seq_len - output_seq_len
    start_x_idx = np.random.choice(range(total_start_points), total_start_points, replace = False)
    
    input_batch_idxs = [(range(i, i+input_seq_len)) for i in start_x_idx]
    input_seq = np.take(x, input_batch_idxs, axis = 0)
    
    output_batch_idxs = [(range(i+input_seq_len, i+input_seq_len+output_seq_len)) for i in start_x_idx]
    output_seq = np.take(x, output_batch_idxs, axis = 0)
    
    input_seq =(input_seq.reshape(input_seq.shape[0],input_seq.shape[1],num_input_features))
    output_seq=(output_seq.reshape(output_seq.shape[0],output_seq.shape[1],num_output_features))
    
    return input_seq, output_seq

# %%
input_seq, output_seq = generate_train_sequences(X_train)
print(input_seq.shape, output_seq.shape)
# Out:
# (2337, 16, 1) (2337, 16, 1)

# %% [markdown]
# ***Encoder***

# %%
# Define an input series and encode it with an LSTM. 

encoder_inputs = tf.keras.layers.Input(shape=(None, num_input_features)) 
encoder = LSTM(128, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the final states. These represent the "context"
# vector that we use as the basis for decoding.
encoder_states = [state_h, state_c]

# %% [markdown]
# ***Decoder***

# %%
# Set up the decoder, using `encoder_states` as initial state.
# This is where teacher forcing inputs are fed in.
decoder_inputs = tf.keras.layers.Input(shape=(None, 1)) 


# We set up our decoder using `encoder_states` as initial state.  
# We return full output sequences and return internal states as well. 
# We don't use the return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(128,  return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)

decoder_dense = Dense(1) # 1 continuous output at each timestep
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
#model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model = Model(inputs=[encoder_inputs, decoder_inputs], outputs=decoder_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None, 1)]    0
# __________________________________________________________________________________________________
# unified_lstm (UnifiedLSTM)      [(None, 128), (None, 66560       input_1[0][0]
# __________________________________________________________________________________________________
# unified_lstm_1 (UnifiedLSTM)    [(None, None, 128),  66560       input_2[0][0]
#                                                                  unified_lstm[0][1]
#                                                                  unified_lstm[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 1)      129         unified_lstm_1[0][0]
# ==================================================================================================
# Total params: 133,249
# Trainable params: 133,249
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(lr=0.001)
model.compile(loss='mse', optimizer= optimizer, metrics=[ 'mse'])

# %%
input_seq, output_seq = generate_train_sequences(X_train)

encoder_input_data = input_seq
decoder_target_data = output_seq
decoder_input_data = np.zeros(decoder_target_data.shape)

history = model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
                             batch_size=batch_size,
                             epochs= 100,
                             validation_split=0.1, 
                             shuffle=False)
# Out:
# Train on 2103 samples, validate on 234 samples
# Epoch 1/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0650 - mse: 0.0650 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 2/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0578 - mse: 0.0578 - val_loss: 0.0568 - val_mse: 0.0568
# Epoch 3/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0575 - mse: 0.0575 - val_loss: 0.0556 - val_mse: 0.0556
# Epoch 4/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0573 - mse: 0.0573 - val_loss: 0.0554 - val_mse: 0.0554
# Epoch 5/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0572 - mse: 0.0572 - val_loss: 0.0557 - val_mse: 0.0557
# Epoch 6/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0571 - mse: 0.0571 - val_loss: 0.0563 - val_mse: 0.0563
# Epoch 7/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0570 - mse: 0.0570 - val_loss: 0.0568 - val_mse: 0.0568
# Epoch 8/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0569 - mse: 0.0569 - val_loss: 0.0573 - val_mse: 0.0573
# Epoch 9/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0568 - mse: 0.0568 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 10/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0567 - mse: 0.0567 - val_loss: 0.0585 - val_mse: 0.0585
# Epoch 11/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0567 - mse: 0.0567 - val_loss: 0.0585 - val_mse: 0.0585
# Epoch 12/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0567 - mse: 0.0567 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 13/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0566 - mse: 0.0566 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 14/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0564 - mse: 0.0564 - val_loss: 0.0574 - val_mse: 0.0574
# Epoch 15/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0562 - mse: 0.0562 - val_loss: 0.0567 - val_mse: 0.0567
# Epoch 16/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0502 - mse: 0.0502 - val_loss: 0.0401 - val_mse: 0.0401
# Epoch 17/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0362 - mse: 0.0362 - val_loss: 0.0372 - val_mse: 0.0372
# Epoch 18/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0342 - mse: 0.0342 - val_loss: 0.0354 - val_mse: 0.0354
# Epoch 19/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0342 - mse: 0.0342 - val_loss: 0.0356 - val_mse: 0.0356
# Epoch 20/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0347 - val_mse: 0.0347
# Epoch 21/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0346 - val_mse: 0.0346
# Epoch 22/100
# 2103/2103 [==============================] - ETA: 0s - loss: 0.0325 - mse: 0.032 - 3s 1ms/sample - loss: 0.0325 - mse: 0.0325 - val_loss: 0.0345 - val_mse: 0.0345
# Epoch 23/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0323 - mse: 0.0323 - val_loss: 0.0344 - val_mse: 0.0344
# Epoch 24/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0322 - mse: 0.0322 - val_loss: 0.0343 - val_mse: 0.0343
# Epoch 25/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0321 - mse: 0.0321 - val_loss: 0.0342 - val_mse: 0.0342
# Epoch 26/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0320 - mse: 0.0320 - val_loss: 0.0340 - val_mse: 0.0340
# Epoch 27/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0319 - mse: 0.0319 - val_loss: 0.0336 - val_mse: 0.0336
# Epoch 28/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0318 - mse: 0.0318 - val_loss: 0.0332 - val_mse: 0.0332
# Epoch 29/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0317 - mse: 0.0317 - val_loss: 0.0333 - val_mse: 0.0333
# Epoch 30/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0315 - mse: 0.0315 - val_loss: 0.0327 - val_mse: 0.0327
# Epoch 31/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0315 - mse: 0.0315 - val_loss: 0.0327 - val_mse: 0.0327
# Epoch 32/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0313 - mse: 0.0313 - val_loss: 0.0331 - val_mse: 0.0331
# Epoch 33/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0311 - mse: 0.0311 - val_loss: 0.0330 - val_mse: 0.0330
# Epoch 34/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0310 - mse: 0.0310 - val_loss: 0.0329 - val_mse: 0.0329
# Epoch 35/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0308 - mse: 0.0308 - val_loss: 0.0330 - val_mse: 0.0330
# Epoch 36/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0308 - mse: 0.0308 - val_loss: 0.0329 - val_mse: 0.0329
# Epoch 37/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0304 - mse: 0.0304 - val_loss: 0.0324 - val_mse: 0.0324
# Epoch 38/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0303 - mse: 0.0303 - val_loss: 0.0327 - val_mse: 0.0327
# Epoch 39/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0301 - mse: 0.0301 - val_loss: 0.0320 - val_mse: 0.0320
# Epoch 40/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0300 - mse: 0.0300 - val_loss: 0.0319 - val_mse: 0.0319
# Epoch 41/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0298 - mse: 0.0298 - val_loss: 0.0315 - val_mse: 0.0315
# Epoch 42/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0296 - mse: 0.0296 - val_loss: 0.0314 - val_mse: 0.0314
# Epoch 43/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0296 - mse: 0.0296 - val_loss: 0.0312 - val_mse: 0.0312
# Epoch 44/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0293 - mse: 0.0293 - val_loss: 0.0307 - val_mse: 0.0307
# Epoch 45/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0291 - mse: 0.0291 - val_loss: 0.0306 - val_mse: 0.0306
# Epoch 46/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0291 - mse: 0.0291 - val_loss: 0.0304 - val_mse: 0.0304
# Epoch 47/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0286 - mse: 0.0286 - val_loss: 0.0303 - val_mse: 0.0303
# Epoch 48/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0282 - mse: 0.0282 - val_loss: 0.0304 - val_mse: 0.0304
# Epoch 49/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0280 - mse: 0.0280 - val_loss: 0.0301 - val_mse: 0.0301
# Epoch 50/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0277 - mse: 0.0277 - val_loss: 0.0302 - val_mse: 0.0302
# Epoch 51/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0275 - mse: 0.0275 - val_loss: 0.0304 - val_mse: 0.0304
# Epoch 52/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0275 - mse: 0.0275 - val_loss: 0.0300 - val_mse: 0.0300
# Epoch 53/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0272 - mse: 0.0272 - val_loss: 0.0303 - val_mse: 0.0303
# Epoch 54/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0269 - mse: 0.0269 - val_loss: 0.0293 - val_mse: 0.0293
# Epoch 55/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0263 - mse: 0.0263 - val_loss: 0.0293 - val_mse: 0.0293
# Epoch 56/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0262 - mse: 0.0262 - val_loss: 0.0291 - val_mse: 0.0291
# Epoch 57/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0258 - mse: 0.0258 - val_loss: 0.0290 - val_mse: 0.0290
# Epoch 58/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0254 - mse: 0.0254 - val_loss: 0.0292 - val_mse: 0.0292
# Epoch 59/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0253 - mse: 0.0253 - val_loss: 0.0290 - val_mse: 0.0290
# Epoch 60/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0258 - mse: 0.0258 - val_loss: 0.0298 - val_mse: 0.0298
# Epoch 61/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0253 - mse: 0.0253 - val_loss: 0.0292 - val_mse: 0.0292
# Epoch 62/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0249 - mse: 0.0249 - val_loss: 0.0286 - val_mse: 0.0286
# Epoch 63/100
# 2103/2103 [==============================] - 3s 2ms/sample - loss: 0.0246 - mse: 0.0246 - val_loss: 0.0297 - val_mse: 0.0297
# Epoch 64/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0243 - mse: 0.0243 - val_loss: 0.0292 - val_mse: 0.0292
# Epoch 65/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0282 - val_mse: 0.0282
# Epoch 66/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0289 - val_mse: 0.0289
# Epoch 67/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0277 - val_mse: 0.0277
# Epoch 68/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0228 - mse: 0.0228 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 69/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0224 - mse: 0.0224 - val_loss: 0.0265 - val_mse: 0.0265
# Epoch 70/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0221 - mse: 0.0221 - val_loss: 0.0267 - val_mse: 0.0267
# Epoch 71/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0260 - val_mse: 0.0260
# Epoch 72/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0217 - mse: 0.0217 - val_loss: 0.0265 - val_mse: 0.0265
# Epoch 73/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0258 - val_mse: 0.0258
# Epoch 74/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0270 - val_mse: 0.0270
# Epoch 75/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0210 - mse: 0.0210 - val_loss: 0.0269 - val_mse: 0.0269
# Epoch 76/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0270 - val_mse: 0.0270
# Epoch 77/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0214 - mse: 0.0214 - val_loss: 0.0278 - val_mse: 0.0278
# Epoch 78/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0229 - mse: 0.0229 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 79/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0262 - val_mse: 0.0262
# Epoch 80/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0262 - val_mse: 0.0262
# Epoch 81/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0267 - val_mse: 0.0267
# Epoch 82/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0263 - val_mse: 0.0263
# Epoch 83/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0259 - val_mse: 0.0259
# Epoch 84/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0255 - val_mse: 0.0255
# Epoch 85/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0270 - val_mse: 0.0270
# Epoch 86/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0260 - val_mse: 0.0260
# Epoch 87/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0261 - val_mse: 0.0261
# Epoch 88/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0253 - val_mse: 0.0253
# Epoch 89/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0253 - val_mse: 0.0253
# Epoch 90/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0253 - val_mse: 0.0253
# Epoch 91/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0249 - val_mse: 0.0249
# Epoch 92/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0246 - val_mse: 0.0246
# Epoch 93/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0168 - mse: 0.0168 - val_loss: 0.0253 - val_mse: 0.0253
# Epoch 94/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0248 - val_mse: 0.0248
# Epoch 95/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0250 - val_mse: 0.0250
# Epoch 96/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 97/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0243 - val_mse: 0.0243
# Epoch 98/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0247 - val_mse: 0.0247
# Epoch 99/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0237 - val_mse: 0.0237
# Epoch 100/100
# 2103/2103 [==============================] - 3s 1ms/sample - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0235 - val_mse: 0.0235

# %%
#***************************************Model validation loss*****************************************
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
#plt.title('Model Loss')
plt.ylabel('Mean sequared error loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ***Inference model***

# %%
# define inference encoder
n_units = 128

encoder_model = tf.keras.Model(encoder_inputs, encoder_states)
    
# define inference decoder
decoder_state_input_h = Input(shape=(n_units,))
decoder_state_input_c = Input(shape=(n_units,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = tf.keras.Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# %% [markdown]
# ***Prediction***

# %%
def predict(x, encoder_model, decoder_model, num_steps_to_predict):
    
    y_predicted = []

    # Encode the values as a state vector
    states = encoder_model.predict(x)

    # The states must be a list
    if not isinstance(states, list):
        states = [states]

    # Generate first value of the decoder input sequence
    decoder_input = np.zeros((x.shape[0], 1, 1))


    for _ in range(num_steps_to_predict):
        outputs_and_states = decoder_model.predict([decoder_input] + states, batch_size=batch_size)
        output = outputs_and_states[0]
        states = outputs_and_states[1:]

        # add predicted value
        y_predicted.append(output)

    return np.concatenate(y_predicted, axis=1)

# %%
def generate_test_samples(x = X_test, y = y_test, input_seq_len = input_seq_len, output_seq_len = output_seq_len):
    
    total_samples = x.shape[0]
    
    input_batch_idxs = [list(range(i, i+input_seq_len)) for i in range((total_samples-input_seq_len-output_seq_len))]
    input_seq = np.take(x, input_batch_idxs, axis = 0)
    
    output_batch_idxs = [list(range(i+input_seq_len, i+input_seq_len+output_seq_len)) for i in range((total_samples-input_seq_len-output_seq_len))]
    output_seq = np.take(y, output_batch_idxs, axis = 0)
    
    return input_seq, output_seq

# %%
X_test, y_test = generate_test_samples()
print(X_test.shape, y_test.shape)
# Out:
# (561, 16, 1) (561, 16, 1)

# %%
#from utils import plot_prediction
num_steps_to_predict = 16

y_test_predicted = predict(X_test, encoder_model, decoder_model, num_steps_to_predict)
y_test_predicted.shape
# Out:
# (561, 16, 1)

# %%
y_test.shape
# Out:
# (561, 16, 1)

# %% [markdown]
# ***Plotting***

# %% [raw]
# #Select  random examples to plot
# indices = np.random.choice(range(X_test.shape[0]), replace=False, size=10)
#
# for index in indices:
#     plt.plot(y_test[index, :], y_test_predicted[index, :])

# %%
y_test_predicted = y_test_predicted.reshape(y_test_predicted.shape[0], y_test_predicted.shape[1])
y_test_predicted_inv = scaler.inverse_transform(y_test_predicted)

y_test = y_test.reshape(y_test.shape[0], y_test.shape[1])
y_test_inv = scaler.inverse_transform(y_test)

# %%
plt.plot(y_test_predicted_inv[:100], label = "pred", color ='blue')
plt.plot(y_test_inv[:100], label = "actual", color= 'yellow')
plt.show()

# %%
#********************* Actual value, Predicted value and Prediction Error ***************

plt.figure(figsize = (15, 5))
plt.xlabel("Epoch")
plt.ylabel("Email traffic")
plt.plot(y_test_inv[:,0], label="True value", linewidth=1,linestyle="--",color= 'green')
plt.plot(y_test_predicted_inv[:,0], label="Predicted value", linewidth=1,color='blue')

error = abs(y_test_inv[:,0] - y_test_predicted_inv[:,0])

plt.plot(error, label='Error',color= 'orange', linewidth=1, linestyle="--")
plt.legend()
plt.show()

#******************************* True value vs Prediction **********************/

plt.figure(figsize = (15, 5))
plt.xlabel("Epoch")
plt.ylabel("Email traffic")
plt.plot (y_test_inv[:,0], label="True value", linewidth=1,color= 'green', linestyle="--")
plt.plot(y_test_predicted_inv[:,0], label="Predicted value", linewidth=1,color='blue')
plt.legend()
plt.show()

# %% [markdown]
# ***Performance Evaluation metrics***

# %%
models = pd.DataFrame(index=['MAPE','MAE'], 
                      columns=['seq2seq', 'LSTM_many_to_many','CNN_many_to_many'])

# %%
import tensorflow.keras.backend as K
from sklearn.metrics import mean_absolute_error

#def rpe1(y_true, y_pred):
    #y_true, y_pred = np.array(y_true), np.array(y_pred)
    #return np.mean(y_true - y_pred)/y_true * 100


def mean_absolute_error1(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs(y_true - y_pred)) * 100


def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


#models.loc['rmse','seq2seq'] = np.sqrt(mean_squared_error(y_test, y_test_predicted))
models.loc['MAPE','seq2seq'] = mean_absolute_percentage_error(y_test, y_test_predicted)
models.loc['MAE', 'seq2seq'] = mean_absolute_error(y_test, y_test_predicted)*100
#models.loc['mae2', 'seq2seq'] = mean_absolute_error1(y_test, y_test_predicted)


# Prediction Time !!!!
mse = round(mean_squared_error(y_test, y_test_predicted), 2)
print('MSE', mse)
rmse = round(sqrt(mse), 2)
print('RMSE', rmse)
# Out:
# MSE 0.04
# RMSE 0.2

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter((y_test_predicted), y_test, s=4)
ax.plot(y_test, y_test, color='red')
ax.set_title('seq2seq model: G16B3_QP10 predicted frame')
ax.set_xlabel('Predicted frame_size')
ax.set_ylabel('Observed frame_size');

# %% [markdown]
# # Multistep model

# %%
#import data
data2 = pd.read_csv("../VIDEO TRAFFIC/FINAL comparison -benchmark models/data/nbc news G16B3-QP = 10-1.csv",
                  names=['decoded_frame','arrival_time', 'video_frame', 
                                         'frame_size', 'x', 'y', 'z'])

# %%
data2.head()
# Out:
#    decoded_frame  arrival_time video_frame  frame_size       x       y       z
# 0             16     533.33333           I      237784  52.353  52.474  52.951
# 1             13     433.33333           B      191888  48.114  49.612  50.446
# 2             14     466.66667           B      198992  48.003  49.608  50.231
# 3             15     500.00000           B      136112  48.290  50.312  51.118
# 4             20     666.66667           P      296416  49.951  50.910  51.201

# %%
data2.dropna(0,inplace= True)

# %%
#drop decoded frame column
data2.drop(('decoded_frame'), axis=1, inplace=True)

data2.drop(('x'), axis=1, inplace=True)
data2.drop(('y'), axis=1, inplace=True)
data2.drop(('z'), axis=1, inplace=True)

# %%
# Label encoding of species column numerically
le = LabelEncoder()
le.fit(data2['video_frame'])
print(list(le.classes_))
data2['video_frame'] = le.transform(data2['video_frame'])
# Out:
# ['B', 'I', 'P']

# %%
data2.head(5)
# Out:
#    arrival_time  video_frame  frame_size
# 0     533.33333            1      237784
# 1     433.33333            0      191888
# 2     466.66667            0      198992
# 3     500.00000            0      136112
# 4     666.66667            2      296416

# %%
# data labels
labels_index = { "B" : 0, "I" : 1, "P" : 2}

# %%
indexNames1 = data2[data2['video_frame'] == 0 ].index

# Delete these row indexes from dataFrame
data2.drop(indexNames1 , inplace=True)

# %%
data2.head()
# Out:
#     arrival_time  video_frame  frame_size
# 0      533.33333            1      237784
# 4      666.66667            2      296416
# 8      800.00000            2      289312
# 12     933.33333            2      288384
# 16    1066.66667            1      259272

# %%
data2.frame_size.dropna(0, inplace=True)

# %%
dataset2 = data2.frame_size.values #numpy.ndarray
data2 = data2.astype ('float32')
#dataset = dataset.astype('float32')
dataset2.shape
# Out:
# (2962,)

# %%
dataset2 = pd.DataFrame(dataset2)
print(dataset2.shape)
# Out:
# (2962, 1)

# %%
# *****************split into train and test sets********************

test_split = int(len(dataset2) * 0.8)

train2 = dataset2[:test_split]
test2 = dataset2[test_split:]

# %%
#********Data normalization**************************

scaler = MinMaxScaler(feature_range=(-1, 1))

train2 = scaler.fit_transform(train2)
test2= scaler.transform(test2)

# %%
#****************************Create lagged time series dataset*******************

def prepare_seq2seq_data(dataset, look_back, look_ahead):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - look_ahead):
        input_seq = dataset[i:(i + look_back)]
        output_seq = dataset[i + look_back:(i + look_back + look_ahead)]
        dataX.append(input_seq)
        dataY.append(output_seq)

    dataX = np.reshape(np.array(dataX),[-1,look_back])
    dataY = np.reshape(np.array(dataY),[-1,look_ahead])
    #print (dataY.shape)
    return dataX,dataY

# %%
look_back = 16
look_ahead = 16

X_train, y_train = prepare_seq2seq_data(train2, look_back, look_ahead)
X_test, y_test = prepare_seq2seq_data(test2, look_back, look_ahead)

# %%
#*******Reshape from[samples, timesteps] into [samples, timesteps, features]*************

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

print('X_train',X_train.shape)
print('X_test', X_test.shape)

# convert 1 D to 2D array
#test_y = test_y.reshape((test_y.shape[0], 1))
#print(test_y.shape)
# Out:
# X_train (2337, 16, 1)
# X_test (561, 16, 1)

# %% [markdown]
# ***LSTM model multistep***

# %%
#********************Build Model****************************

def lstm_model():
    
    model = tf.keras.models.Sequential()
    model.add(LSTM(128, input_shape=(look_back,1),kernel_regularizer=regularizers.l2(0.001)
                ))
    #model.add(tf.keras.layers.Dropout(rate=0.20))
    #model.add(LSTM(64, kernel_regularizer=regularizers.l2(0.001)))
    #model.add(tf.keras.layers.Dropout(rate=0.20))
    #model.add(LSTM(128, kernel_initializer='glorot_uniform',activation='relu'))
    model.add(Dense(look_ahead))
    model.summary()
    
     #optimizer = tf.keras.optimizers.Adam(lr=0.0001)
    model.compile(optimizer= 'adam', loss='mse')
      
    return model

# %%
#*******************Train the model******************************

callback_early_stopping = EarlyStopping(monitor='val_loss', patience=1000, verbose=1)
callbacks = [callback_early_stopping]

model_lstm =lstm_model()


history_lstm = model_lstm.fit(X_train, y_train, batch_size = 32,validation_split=0.2, epochs =100, verbose=1,
                    callbacks=callbacks, shuffle=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# unified_lstm_2 (UnifiedLSTM) (None, 128)               66560
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                2064
# =================================================================
# Total params: 68,624
# Trainable params: 68,624
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1869 samples, validate on 468 samples
# Epoch 1/100
# 1869/1869 [==============================] - 1s 557us/sample - loss: 0.1255 - val_loss: 0.0536
# Epoch 2/100
# 1869/1869 [==============================] - 1s 309us/sample - loss: 0.0637 - val_loss: 0.0518
# Epoch 3/100
# 1869/1869 [==============================] - 1s 325us/sample - loss: 0.0637 - val_loss: 0.0516
# Epoch 4/100
# 1869/1869 [==============================] - 1s 318us/sample - loss: 0.0634 - val_loss: 0.0517
# Epoch 5/100
# 1869/1869 [==============================] - 1s 293us/sample - loss: 0.0629 - val_loss: 0.0517
# Epoch 6/100
# 1869/1869 [==============================] - 1s 314us/sample - loss: 0.0623 - val_loss: 0.0516
# Epoch 7/100
# 1869/1869 [==============================] - 1s 334us/sample - loss: 0.0618 - val_loss: 0.0514
# Epoch 8/100
# 1869/1869 [==============================] - 1s 327us/sample - loss: 0.0613 - val_loss: 0.0512
# Epoch 9/100
# 1869/1869 [==============================] - 1s 325us/sample - loss: 0.0606 - val_loss: 0.0509
# Epoch 10/100
# 1869/1869 [==============================] - 1s 344us/sample - loss: 0.0597 - val_loss: 0.0506
# Epoch 11/100
# 1869/1869 [==============================] - 1s 328us/sample - loss: 0.0584 - val_loss: 0.0502
# Epoch 12/100
# 1869/1869 [==============================] - 1s 329us/sample - loss: 0.0565 - val_loss: 0.0497
# Epoch 13/100
# 1869/1869 [==============================] - 1s 332us/sample - loss: 0.0529 - val_loss: 0.0495
# Epoch 14/100
# 1869/1869 [==============================] - 1s 338us/sample - loss: 0.0490 - val_loss: 0.0491
# Epoch 15/100
# 1869/1869 [==============================] - 1s 345us/sample - loss: 0.0473 - val_loss: 0.0487
# Epoch 16/100
# 1869/1869 [==============================] - 1s 351us/sample - loss: 0.0463 - val_loss: 0.0486
# Epoch 17/100
# 1869/1869 [==============================] - 1s 326us/sample - loss: 0.0443 - val_loss: 0.0482
# Epoch 18/100
# 1869/1869 [==============================] - 1s 330us/sample - loss: 0.0410 - val_loss: 0.0478
# Epoch 19/100
# 1869/1869 [==============================] - 1s 300us/sample - loss: 0.0395 - val_loss: 0.0475
# Epoch 20/100
# 1869/1869 [==============================] - 1s 289us/sample - loss: 0.0385 - val_loss: 0.0468
# Epoch 21/100
# 1869/1869 [==============================] - 1s 321us/sample - loss: 0.0386 - val_loss: 0.0471
# Epoch 22/100
# 1869/1869 [==============================] - 1s 284us/sample - loss: 0.0377 - val_loss: 0.0467
# Epoch 23/100
# 1869/1869 [==============================] - 1s 289us/sample - loss: 0.0368 - val_loss: 0.0464
# Epoch 24/100
# 1869/1869 [==============================] - 1s 291us/sample - loss: 0.0361 - val_loss: 0.0461
# Epoch 25/100
# 1869/1869 [==============================] - 1s 295us/sample - loss: 0.0356 - val_loss: 0.0458
# Epoch 26/100
# 1869/1869 [==============================] - 1s 290us/sample - loss: 0.0353 - val_loss: 0.0457
# Epoch 27/100
# 1869/1869 [==============================] - 1s 295us/sample - loss: 0.0351 - val_loss: 0.0455
# Epoch 28/100
# 1869/1869 [==============================] - 1s 289us/sample - loss: 0.0349 - val_loss: 0.0454
# Epoch 29/100
# 1869/1869 [==============================] - 1s 295us/sample - loss: 0.0347 - val_loss: 0.0453
# Epoch 30/100
# 1869/1869 [==============================] - 1s 294us/sample - loss: 0.0347 - val_loss: 0.0453
# Epoch 31/100
# 1869/1869 [==============================] - 1s 293us/sample - loss: 0.0345 - val_loss: 0.0452
# Epoch 32/100
# 1869/1869 [==============================] - 1s 288us/sample - loss: 0.0345 - val_loss: 0.0451
# Epoch 33/100
# 1869/1869 [==============================] - 1s 293us/sample - loss: 0.0342 - val_loss: 0.0451
# Epoch 34/100
# 1869/1869 [==============================] - 1s 284us/sample - loss: 0.0343 - val_loss: 0.0450
# Epoch 35/100
# 1869/1869 [==============================] - 1s 295us/sample - loss: 0.0340 - val_loss: 0.0451
# Epoch 36/100
# 1869/1869 [==============================] - 1s 285us/sample - loss: 0.0343 - val_loss: 0.0450
# Epoch 37/100
# 1869/1869 [==============================] - 1s 295us/sample - loss: 0.0338 - val_loss: 0.0452
# Epoch 38/100
# 1869/1869 [==============================] - 1s 294us/sample - loss: 0.0343 - val_loss: 0.0450
# Epoch 39/100
# 1869/1869 [==============================] - 1s 295us/sample - loss: 0.0337 - val_loss: 0.0454
# Epoch 40/100
# 1869/1869 [==============================] - 1s 298us/sample - loss: 0.0343 - val_loss: 0.0449
# Epoch 41/100
# 1869/1869 [==============================] - 1s 290us/sample - loss: 0.0335 - val_loss: 0.0454
# Epoch 42/100
# 1869/1869 [==============================] - 1s 294us/sample - loss: 0.0342 - val_loss: 0.0448
# Epoch 43/100
# 1869/1869 [==============================] - 1s 294us/sample - loss: 0.0334 - val_loss: 0.0454
# Epoch 44/100
# 1869/1869 [==============================] - 1s 294us/sample - loss: 0.0340 - val_loss: 0.0447
# Epoch 45/100
# 1869/1869 [==============================] - 1s 284us/sample - loss: 0.0333 - val_loss: 0.0453
# Epoch 46/100
# 1869/1869 [==============================] - 1s 295us/sample - loss: 0.0338 - val_loss: 0.0446
# Epoch 47/100
# 1869/1869 [==============================] - 1s 295us/sample - loss: 0.0332 - val_loss: 0.0453
# Epoch 48/100
# 1869/1869 [==============================] - 1s 299us/sample - loss: 0.0337 - val_loss: 0.0446
# Epoch 49/100
# 1869/1869 [==============================] - 1s 299us/sample - loss: 0.0331 - val_loss: 0.0452
# Epoch 50/100
# 1869/1869 [==============================] - 1s 292us/sample - loss: 0.0335 - val_loss: 0.0446
# Epoch 51/100
# 1869/1869 [==============================] - 1s 292us/sample - loss: 0.0329 - val_loss: 0.0451
# Epoch 52/100
# 1869/1869 [==============================] - 1s 281us/sample - loss: 0.0334 - val_loss: 0.0445
# Epoch 53/100
# 1869/1869 [==============================] - 1s 291us/sample - loss: 0.0328 - val_loss: 0.0451
# Epoch 54/100
# 1869/1869 [==============================] - 1s 295us/sample - loss: 0.0332 - val_loss: 0.0445
# Epoch 55/100
# 1869/1869 [==============================] - 1s 284us/sample - loss: 0.0327 - val_loss: 0.0450
# Epoch 56/100
# 1869/1869 [==============================] - 1s 294us/sample - loss: 0.0331 - val_loss: 0.0445
# Epoch 57/100
# 1869/1869 [==============================] - 1s 294us/sample - loss: 0.0326 - val_loss: 0.0450
# Epoch 58/100
# 1869/1869 [==============================] - 1s 285us/sample - loss: 0.0330 - val_loss: 0.0445
# Epoch 59/100
# 1869/1869 [==============================] - 1s 295us/sample - loss: 0.0325 - val_loss: 0.0449
# Epoch 60/100
# 1869/1869 [==============================] - 1s 294us/sample - loss: 0.0328 - val_loss: 0.0445
# Epoch 61/100
# 1869/1869 [==============================] - 1s 286us/sample - loss: 0.0324 - val_loss: 0.0449
# Epoch 62/100
# 1869/1869 [==============================] - 1s 290us/sample - loss: 0.0327 - val_loss: 0.0445
# Epoch 63/100
# 1869/1869 [==============================] - 1s 288us/sample - loss: 0.0323 - val_loss: 0.0449
# Epoch 64/100
# 1869/1869 [==============================] - 1s 280us/sample - loss: 0.0326 - val_loss: 0.0446
# Epoch 65/100
# 1869/1869 [==============================] - 1s 282us/sample - loss: 0.0322 - val_loss: 0.0449
# Epoch 66/100
# 1869/1869 [==============================] - 1s 294us/sample - loss: 0.0325 - val_loss: 0.0446
# Epoch 67/100
# 1869/1869 [==============================] - 1s 293us/sample - loss: 0.0321 - val_loss: 0.0450
# Epoch 68/100
# 1869/1869 [==============================] - 1s 286us/sample - loss: 0.0324 - val_loss: 0.0446
# Epoch 69/100
# 1869/1869 [==============================] - 1s 286us/sample - loss: 0.0321 - val_loss: 0.0450
# Epoch 70/100
# 1869/1869 [==============================] - 1s 300us/sample - loss: 0.0323 - val_loss: 0.0446
# Epoch 71/100
# 1869/1869 [==============================] - 1s 286us/sample - loss: 0.0320 - val_loss: 0.0449
# Epoch 72/100
# 1869/1869 [==============================] - 1s 285us/sample - loss: 0.0322 - val_loss: 0.0446
# Epoch 73/100
# 1869/1869 [==============================] - 1s 294us/sample - loss: 0.0319 - val_loss: 0.0449
# Epoch 74/100
# 1869/1869 [==============================] - 1s 287us/sample - loss: 0.0320 - val_loss: 0.0446
# Epoch 75/100
# 1869/1869 [==============================] - 1s 284us/sample - loss: 0.0319 - val_loss: 0.0449
# Epoch 76/100
# 1869/1869 [==============================] - 1s 296us/sample - loss: 0.0318 - val_loss: 0.0446
# Epoch 77/100
# 1869/1869 [==============================] - 1s 279us/sample - loss: 0.0319 - val_loss: 0.0449
# Epoch 78/100
# 1869/1869 [==============================] - 1s 300us/sample - loss: 0.0317 - val_loss: 0.0445
# Epoch 79/100
# 1869/1869 [==============================] - 1s 282us/sample - loss: 0.0318 - val_loss: 0.0448
# Epoch 80/100
# 1869/1869 [==============================] - 1s 288us/sample - loss: 0.0315 - val_loss: 0.0445
# Epoch 81/100
# 1869/1869 [==============================] - 1s 295us/sample - loss: 0.0317 - val_loss: 0.0448
# Epoch 82/100
# 1869/1869 [==============================] - 1s 285us/sample - loss: 0.0314 - val_loss: 0.0445
# Epoch 83/100
# 1869/1869 [==============================] - 1s 286us/sample - loss: 0.0316 - val_loss: 0.0448
# Epoch 84/100
# 1869/1869 [==============================] - 1s 286us/sample - loss: 0.0312 - val_loss: 0.0445
# Epoch 85/100
# 1869/1869 [==============================] - 1s 294us/sample - loss: 0.0315 - val_loss: 0.0448
# Epoch 86/100
# 1869/1869 [==============================] - 1s 299us/sample - loss: 0.0311 - val_loss: 0.0445
# Epoch 87/100
# 1869/1869 [==============================] - 1s 281us/sample - loss: 0.0314 - val_loss: 0.0448
# Epoch 88/100
# 1869/1869 [==============================] - 1s 292us/sample - loss: 0.0311 - val_loss: 0.0445
# Epoch 89/100
# 1869/1869 [==============================] - 1s 290us/sample - loss: 0.0313 - val_loss: 0.0449
# Epoch 90/100
# 1869/1869 [==============================] - 1s 291us/sample - loss: 0.0310 - val_loss: 0.0446
# Epoch 91/100
# 1869/1869 [==============================] - 1s 284us/sample - loss: 0.0312 - val_loss: 0.0449
# Epoch 92/100
# 1869/1869 [==============================] - 1s 291us/sample - loss: 0.0309 - val_loss: 0.0446
# Epoch 93/100
# 1869/1869 [==============================] - 1s 289us/sample - loss: 0.0311 - val_loss: 0.0449
# Epoch 94/100
# 1869/1869 [==============================] - 1s 293us/sample - loss: 0.0308 - val_loss: 0.0446
# Epoch 95/100
# 1869/1869 [==============================] - 1s 299us/sample - loss: 0.0310 - val_loss: 0.0449
# Epoch 96/100
# 1869/1869 [==============================] - 1s 308us/sample - loss: 0.0307 - val_loss: 0.0447
# Epoch 97/100
# 1869/1869 [==============================] - 1s 309us/sample - loss: 0.0309 - val_loss: 0.0449
# Epoch 98/100
# 1869/1869 [==============================] - 1s 301us/sample - loss: 0.0307 - val_loss: 0.0447
# Epoch 99/100
# 1869/1869 [==============================] - 1s 328us/sample - loss: 0.0309 - val_loss: 0.0449
# Epoch 100/100
# 1869/1869 [==============================] - 1s 335us/sample - loss: 0.0306 - val_loss: 0.0447

# %%
# Prediction Time !!!!


yhat_lstm = model_lstm.predict(X_test)

mse_lstm = mean_squared_error(y_test, yhat_lstm)
rmse_lstm = sqrt(mse_lstm)

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


#models.loc['rmse','LSTM_many_to_many'] = np.sqrt(mean_squared_error(y_test, yhat_lstm))
models.loc['MAPE','LSTM_many_to_many'] = mean_absolute_percentage_error(y_test, yhat_lstm)
models.loc['MAE','LSTM_many_to_many'] = mean_absolute_error(y_test, yhat_lstm)*100

# %% [markdown]
# ***CNN model multistep***

# %%
#********************Build Model****************************

def cnn_model():
    
    model = tf.keras.models.Sequential()
    model.add(Conv1D(filters=128, kernel_size=3, strides=1, input_shape=(look_back,1)
                    ))
    model.add(MaxPooling1D(pool_size=(2)))
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(look_ahead))
    model.compile(optimizer='adam', loss='mse')
    model.summary()
      
    return model

# %%
model_cnn =cnn_model()

history_cnn = model_cnn.fit(X_train, y_train, batch_size = 32,validation_split=0.2, epochs = 100, verbose=1,
                    callbacks=callbacks, shuffle=False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 14, 128)           512
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 7, 128)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 896)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 896)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                14352
# =================================================================
# Total params: 14,864
# Trainable params: 14,864
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1869 samples, validate on 468 samples
# Epoch 1/100
# 1869/1869 [==============================] - 0s 199us/sample - loss: 0.0874 - val_loss: 0.0498
# Epoch 2/100
# 1869/1869 [==============================] - 0s 68us/sample - loss: 0.0498 - val_loss: 0.0472
# Epoch 3/100
# 1869/1869 [==============================] - 0s 70us/sample - loss: 0.0453 - val_loss: 0.0461
# Epoch 4/100
# 1869/1869 [==============================] - 0s 70us/sample - loss: 0.0426 - val_loss: 0.0452
# Epoch 5/100
# 1869/1869 [==============================] - 0s 71us/sample - loss: 0.0407 - val_loss: 0.0445
# Epoch 6/100
# 1869/1869 [==============================] - 0s 79us/sample - loss: 0.0392 - val_loss: 0.0442
# Epoch 7/100
# 1869/1869 [==============================] - 0s 89us/sample - loss: 0.0383 - val_loss: 0.0441
# Epoch 8/100
# 1869/1869 [==============================] - 0s 80us/sample - loss: 0.0376 - val_loss: 0.0439
# Epoch 9/100
# 1869/1869 [==============================] - 0s 80us/sample - loss: 0.0371 - val_loss: 0.0439
# Epoch 10/100
# 1869/1869 [==============================] - 0s 80us/sample - loss: 0.0372 - val_loss: 0.0440
# Epoch 11/100
# 1869/1869 [==============================] - 0s 76us/sample - loss: 0.0367 - val_loss: 0.0440
# Epoch 12/100
# 1869/1869 [==============================] - 0s 79us/sample - loss: 0.0361 - val_loss: 0.0440
# Epoch 13/100
# 1869/1869 [==============================] - 0s 96us/sample - loss: 0.0362 - val_loss: 0.0440
# Epoch 14/100
# 1869/1869 [==============================] - 0s 82us/sample - loss: 0.0362 - val_loss: 0.0441
# Epoch 15/100
# 1869/1869 [==============================] - 0s 91us/sample - loss: 0.0360 - val_loss: 0.0440
# Epoch 16/100
# 1869/1869 [==============================] - 0s 94us/sample - loss: 0.0360 - val_loss: 0.0442
# Epoch 17/100
# 1869/1869 [==============================] - 0s 80us/sample - loss: 0.0363 - val_loss: 0.0443
# Epoch 18/100
# 1869/1869 [==============================] - 0s 79us/sample - loss: 0.0359 - val_loss: 0.0443
# Epoch 19/100
# 1869/1869 [==============================] - 0s 84us/sample - loss: 0.0355 - val_loss: 0.0443
# Epoch 20/100
# 1869/1869 [==============================] - 0s 77us/sample - loss: 0.0357 - val_loss: 0.0447
# Epoch 21/100
# 1869/1869 [==============================] - 0s 71us/sample - loss: 0.0355 - val_loss: 0.0441
# Epoch 22/100
# 1869/1869 [==============================] - 0s 70us/sample - loss: 0.0354 - val_loss: 0.0444
# Epoch 23/100
# 1869/1869 [==============================] - 0s 72us/sample - loss: 0.0355 - val_loss: 0.0447
# Epoch 24/100
# 1869/1869 [==============================] - 0s 69us/sample - loss: 0.0350 - val_loss: 0.0441
# Epoch 25/100
# 1869/1869 [==============================] - 0s 70us/sample - loss: 0.0353 - val_loss: 0.0443
# Epoch 26/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0353 - val_loss: 0.0446
# Epoch 27/100
# 1869/1869 [==============================] - 0s 76us/sample - loss: 0.0351 - val_loss: 0.0447
# Epoch 28/100
# 1869/1869 [==============================] - 0s 69us/sample - loss: 0.0351 - val_loss: 0.0445
# Epoch 29/100
# 1869/1869 [==============================] - 0s 69us/sample - loss: 0.0350 - val_loss: 0.0446
# Epoch 30/100
# 1869/1869 [==============================] - 0s 72us/sample - loss: 0.0349 - val_loss: 0.0444
# Epoch 31/100
# 1869/1869 [==============================] - 0s 73us/sample - loss: 0.0347 - val_loss: 0.0441
# Epoch 32/100
# 1869/1869 [==============================] - 0s 77us/sample - loss: 0.0348 - val_loss: 0.0444
# Epoch 33/100
# 1869/1869 [==============================] - 0s 78us/sample - loss: 0.0349 - val_loss: 0.0446
# Epoch 34/100
# 1869/1869 [==============================] - 0s 73us/sample - loss: 0.0348 - val_loss: 0.0447
# Epoch 35/100
# 1869/1869 [==============================] - 0s 78us/sample - loss: 0.0347 - val_loss: 0.0445
# Epoch 36/100
# 1869/1869 [==============================] - 0s 78us/sample - loss: 0.0345 - val_loss: 0.0445
# Epoch 37/100
# 1869/1869 [==============================] - 0s 74us/sample - loss: 0.0347 - val_loss: 0.0445
# Epoch 38/100
# 1869/1869 [==============================] - 0s 70us/sample - loss: 0.0345 - val_loss: 0.0443
# Epoch 39/100
# 1869/1869 [==============================] - 0s 69us/sample - loss: 0.0346 - val_loss: 0.0444
# Epoch 40/100
# 1869/1869 [==============================] - 0s 71us/sample - loss: 0.0344 - val_loss: 0.0446
# Epoch 41/100
# 1869/1869 [==============================] - 0s 69us/sample - loss: 0.0346 - val_loss: 0.0445
# Epoch 42/100
# 1869/1869 [==============================] - 0s 68us/sample - loss: 0.0345 - val_loss: 0.0445
# Epoch 43/100
# 1869/1869 [==============================] - 0s 68us/sample - loss: 0.0346 - val_loss: 0.0443
# Epoch 44/100
# 1869/1869 [==============================] - 0s 71us/sample - loss: 0.0344 - val_loss: 0.0444
# Epoch 45/100
# 1869/1869 [==============================] - 0s 70us/sample - loss: 0.0344 - val_loss: 0.0444
# Epoch 46/100
# 1869/1869 [==============================] - 0s 69us/sample - loss: 0.0343 - val_loss: 0.0445
# Epoch 47/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0340 - val_loss: 0.0445
# Epoch 48/100
# 1869/1869 [==============================] - 0s 70us/sample - loss: 0.0343 - val_loss: 0.0443
# Epoch 49/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0343 - val_loss: 0.0445
# Epoch 50/100
# 1869/1869 [==============================] - 0s 68us/sample - loss: 0.0341 - val_loss: 0.0447
# Epoch 51/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0341 - val_loss: 0.0444
# Epoch 52/100
# 1869/1869 [==============================] - 0s 69us/sample - loss: 0.0343 - val_loss: 0.0444
# Epoch 53/100
# 1869/1869 [==============================] - 0s 79us/sample - loss: 0.0339 - val_loss: 0.0442
# Epoch 54/100
# 1869/1869 [==============================] - 0s 74us/sample - loss: 0.0339 - val_loss: 0.0441
# Epoch 55/100
# 1869/1869 [==============================] - 0s 68us/sample - loss: 0.0343 - val_loss: 0.0445
# Epoch 56/100
# 1869/1869 [==============================] - 0s 78us/sample - loss: 0.0339 - val_loss: 0.0443
# Epoch 57/100
# 1869/1869 [==============================] - 0s 78us/sample - loss: 0.0339 - val_loss: 0.0443
# Epoch 58/100
# 1869/1869 [==============================] - 0s 69us/sample - loss: 0.0341 - val_loss: 0.0442
# Epoch 59/100
# 1869/1869 [==============================] - 0s 73us/sample - loss: 0.0340 - val_loss: 0.0443
# Epoch 60/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0339 - val_loss: 0.0443
# Epoch 61/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0342 - val_loss: 0.0444
# Epoch 62/100
# 1869/1869 [==============================] - 0s 68us/sample - loss: 0.0339 - val_loss: 0.0445
# Epoch 63/100
# 1869/1869 [==============================] - 0s 72us/sample - loss: 0.0338 - val_loss: 0.0440
# Epoch 64/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0340 - val_loss: 0.0445
# Epoch 65/100
# 1869/1869 [==============================] - 0s 65us/sample - loss: 0.0339 - val_loss: 0.0443
# Epoch 66/100
# 1869/1869 [==============================] - 0s 68us/sample - loss: 0.0337 - val_loss: 0.0443
# Epoch 67/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0338 - val_loss: 0.0444
# Epoch 68/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0339 - val_loss: 0.0443
# Epoch 69/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0338 - val_loss: 0.0444
# Epoch 70/100
# 1869/1869 [==============================] - 0s 69us/sample - loss: 0.0337 - val_loss: 0.0446
# Epoch 71/100
# 1869/1869 [==============================] - 0s 65us/sample - loss: 0.0335 - val_loss: 0.0442
# Epoch 72/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0334 - val_loss: 0.0443
# Epoch 73/100
# 1869/1869 [==============================] - 0s 65us/sample - loss: 0.0335 - val_loss: 0.0444
# Epoch 74/100
# 1869/1869 [==============================] - 0s 68us/sample - loss: 0.0335 - val_loss: 0.0445
# Epoch 75/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0334 - val_loss: 0.0444
# Epoch 76/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0335 - val_loss: 0.0441
# Epoch 77/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0336 - val_loss: 0.0442
# Epoch 78/100
# 1869/1869 [==============================] - 0s 68us/sample - loss: 0.0331 - val_loss: 0.0441
# Epoch 79/100
# 1869/1869 [==============================] - 0s 65us/sample - loss: 0.0333 - val_loss: 0.0442
# Epoch 80/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0333 - val_loss: 0.0441
# Epoch 81/100
# 1869/1869 [==============================] - 0s 65us/sample - loss: 0.0334 - val_loss: 0.0443
# Epoch 82/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0332 - val_loss: 0.0441
# Epoch 83/100
# 1869/1869 [==============================] - 0s 65us/sample - loss: 0.0333 - val_loss: 0.0442
# Epoch 84/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0334 - val_loss: 0.0443
# Epoch 85/100
# 1869/1869 [==============================] - 0s 65us/sample - loss: 0.0332 - val_loss: 0.0441
# Epoch 86/100
# 1869/1869 [==============================] - 0s 69us/sample - loss: 0.0334 - val_loss: 0.0442
# Epoch 87/100
# 1869/1869 [==============================] - 0s 65us/sample - loss: 0.0334 - val_loss: 0.0444
# Epoch 88/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0333 - val_loss: 0.0444
# Epoch 89/100
# 1869/1869 [==============================] - 0s 65us/sample - loss: 0.0333 - val_loss: 0.0441
# Epoch 90/100
# 1869/1869 [==============================] - 0s 68us/sample - loss: 0.0334 - val_loss: 0.0442
# Epoch 91/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0332 - val_loss: 0.0441
# Epoch 92/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0329 - val_loss: 0.0442
# Epoch 93/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0332 - val_loss: 0.0444
# Epoch 94/100
# 1869/1869 [==============================] - 0s 67us/sample - loss: 0.0333 - val_loss: 0.0440
# Epoch 95/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0333 - val_loss: 0.0440
# Epoch 96/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0332 - val_loss: 0.0441
# Epoch 97/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0333 - val_loss: 0.0443
# Epoch 98/100
# 1869/1869 [==============================] - 0s 68us/sample - loss: 0.0328 - val_loss: 0.0442
# Epoch 99/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0330 - val_loss: 0.0443
# Epoch 100/100
# 1869/1869 [==============================] - 0s 66us/sample - loss: 0.0332 - val_loss: 0.0441

# %%
#***************************************Model validation loss*****************************************
plt.figure()
plt.plot(history_cnn.history['loss'])
plt.plot(history_cnn.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Validation loss')
plt.xlabel('Epoch')
plt.legend(['Training data loss', 'Validation data loss'], loc='upper right')
plt.show()

# %%
# Prediction Time !!!!
yhat_cnn = model_cnn.predict(X_test)
mse_cnn = mean_squared_error(y_test, yhat_cnn)
rmse_cnn = sqrt(mse_cnn)

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

#models.loc['rmse','CNN_many_to_many'] = np.sqrt(mean_squared_error(y_test, yhat_cnn))
models.loc['MAPE','CNN_many_to_many'] = mean_absolute_percentage_error(y_test, yhat_cnn)
models.loc['MAE','CNN_many_to_many'] = mean_absolute_error(y_test, yhat_cnn)*100

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(model_lstm.predict(X_test), y_test, s=4)
ax.plot(y_test, y_test, color='red')
ax.set_title(' LSTM model: G16B3_QP28 predicted frame')
ax.set_xlabel('Predicted frame_size')
ax.set_ylabel('Observed frame_size');

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(model_cnn.predict(X_test), y_test, s=4)
ax.plot(y_test, y_test, color='red')
ax.set_title('CNN model: G16B3_QP28 predicted frame')
ax.set_xlabel('Predicted frame_size')
ax.set_ylabel('Observed frame_size');

# %%
models
# Out:
#       seq2seq LSTM_many_to_many CNN_many_to_many
# MAPE  84.2278           77.3142          83.1624
# MAE    13.958           11.7814           12.002

# %%
import seaborn as sns
import matplotlib
fig, ax = plt.subplots(figsize=(7,3))

#fig = plt.figure()
#ax = fig.add_subplot(111)
#ax2 = ax.twinx()   # create another axes that shares teh same x-axis as ax
bar_width = 0

#sns.set_style("dark")
#matplotlib.style.use('fivethirtyeight')


models.loc['MAPE'].sort_values().plot(kind='bar', ax=ax,color ='b', alpha=0.9)
models.loc['MAE'].sort_values().plot(kind='bar', ax=ax, color='r', alpha=0.9)
ax.set_title('nbc news G16B3_QP28');
ax.set_xlabel('models')
#ax2.set_ylabel('mape')
ax.set_ylabel('metrics');
ax.tick_params(axis='x', rotation=30)

#plt.xticks(rotation=30, horizontalalignment="center")


plt.legend(loc='best')
plt.show()

# %%
models.plot(kind='bar', width=0.8, figsize=(6,3))
plt.xticks(rotation=30, horizontalalignment="center")
plt.title('nbc news G16B3_QP28');
plt.xlabel('Models')
plt.ylabel('Metrics')
#ax2.set_ylabel('mape')

plt.show()

# %%
# Loss of the model

def plot_history(histories, key=  'loss'):
  #plt.figure(figsize=(15,10))
    
  for name, history in histories:
    plt.plot(history.epoch, history.history[key],
             label=name.title())
    
  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()
  plt.xlim([0,max(history.epoch)])


plot_history([('seq2seq', history),
              ('LSTM_many_to_many', history_lstm),
         
             ('CNN_many_to_many', history_cnn)])

# %%
import seaborn as sns
sns.set_style("dark")


models.plot(kind='bar', width=0.8, figsize=(6,3))
plt.xticks(rotation=30, horizontalalignment="center")
plt.title('NBC news G16B3_QP28');
plt.xlabel('Models')
plt.ylabel('Metrics')
#ax2.set_ylabel('mape')

plt.show()
